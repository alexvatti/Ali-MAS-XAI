# %% [markdown]
# # Web Service Classifcation using DL for top 10,20,30,40,50 Web Service Categories
#
# # Web Service Classification using DL (BI- LSTM)

# %% [markdown]
# ## 1. Load Python Modules

# %%
import pandas as pd
import numpy as np
import re
import os
import pickle
import warnings

# Text Preprocessing
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Bidirectional, Dense, Dropout,GlobalMaxPooling1D,LayerNormalization

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Notebook settings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")
# %matplotlib inline

# Setup directories
os.makedirs("charts", exist_ok=True)
os.makedirs("results", exist_ok=True)
# Out:
# 2025-06-12 12:32:17.622139: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749731537.785063   21322 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749731537.824176   21322 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749731538.167786   21322 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749731538.168090   21322 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749731538.168094   21322 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749731538.168096   21322 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-12 12:32:18.210042: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 2. Generate Report in CSV

# %%
def generate_report_csv(report_dict, confusion_mat, class_labels, output_file="DL-Report.csv"):
    df = pd.DataFrame(report_dict).transpose()

    # Filter only class label rows
    df = df.loc[[str(cls) for cls in class_labels if str(cls) in df.index]].copy()

    # Compute per-class accuracy
    row_sums = confusion_mat.sum(axis=1)
    diagonal = np.diag(confusion_mat)
    per_class_accuracy = (diagonal / row_sums).round(2)

    df['accuracy'] = per_class_accuracy
    if 'support' in df.columns:
        df = df.drop(columns=['support'])

    df.reset_index(inplace=True)
    df.rename(columns={'index': 'Category'}, inplace=True)

    df.to_csv(f"results/{output_file}", index=False)
    print(f"Classification report saved to: {output_file}")

# %% [markdown]
# ## 3. Confusion Matrix - Show - Save

# %%
def generate_confusion_heatmap(cm, class_names, name):
    n_classes = len(class_names)
    figsize = (18, 18) if n_classes >= 40 else (8, 8)

    plt.figure(figsize=figsize)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names, annot_kws={"size": 6})
    plt.title(f'Confusion Matrix: {name}', fontsize=16)
    plt.xlabel('Predicted', fontsize=14)
    plt.ylabel('Actual', fontsize=14)
    plt.xticks(rotation=90, fontsize=8)
    plt.yticks(fontsize=8)
    plt.tight_layout()
    save_path = f"charts/DL_confusion_matrix_{name.replace(' ', '_')}.png"
    plt.savefig(save_path)
    plt.show()
    print(f"Confusion matrix saved to: {save_path}")

# %% [markdown]
# ## 4. Evaluate Model

# %%
def evaluate_and_report(y_test, y_pred, name, labels, class_names):
    print(f"\n {name} Classification Report:\n")
    print(classification_report(y_test, y_pred,target_names=class_names))

    report = classification_report(y_test, y_pred, output_dict=True, labels=labels)
    cm = confusion_matrix(y_test, y_pred, labels=labels)

    generate_report_csv(report, cm, class_labels=labels, output_file=f"DL-Report-{name}.csv")
    generate_confusion_heatmap(cm, class_names, name)

    return {
        "accuracy": accuracy_score(y_test, y_pred),
        "precision": precision_score(y_test, y_pred, average='weighted', zero_division=0),
        "recall": recall_score(y_test, y_pred, average='weighted', zero_division=0),
        "f1_score": f1_score(y_test, y_pred, average='weighted', zero_division=0)
    }

# %% [markdown]
# ## 5. Build - Model

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Initialize tools
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word not in stop_words]
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in stemmed_tokens]

    return " ".join(lemmatized_tokens)


def build_dl_model(input_length, num_classes, model_type="rnn"):
    model = Sequential()
    # Embedding Layer 
    model.add(Embedding(input_dim=10000, output_dim=128, input_length=input_length))
    # 1st BiLSTM with reduced units
    model.add(Bidirectional(LSTM(64, return_sequences=True)))
    model.add(Dropout(0.3))
    # Replacing 2nd BiLSTM with GlobalMaxPooling 
    model.add(LayerNormalization())
    model.add(GlobalMaxPooling1D())
    # Dense Layers (smaller size and stronger dropout)
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    # Output Layer
    model.add(Dense(num_classes, activation='softmax'))
    # Compile
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## 6. Train the Model

# %%
def train_dl_model(df, model_type, name, max_len=150):
    df = df.dropna(subset=["Service Description", "Service Classification"])
    df["Service Description"] = df["Service Description"].apply(clean_text)

    texts = df['Service Description'].values
    labels = df['Service Classification'].values

    tokenizer = Tokenizer(num_words=10000)
    tokenizer.fit_on_texts(texts)
    X_seq = tokenizer.texts_to_sequences(texts)
    X_pad = pad_sequences(X_seq, maxlen=max_len, padding='post')

    le = LabelEncoder()
    y_enc = le.fit_transform(labels)
    y_cat = to_categorical(y_enc)
    num_classes = y_cat.shape[1]

    X_train, X_test, y_train, y_test = train_test_split(X_pad, y_cat, test_size=0.2, random_state=42, stratify=y_cat)

    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_enc), y=y_enc)
    class_weights = dict(enumerate(class_weights))

    model = build_dl_model(input_length=max_len, num_classes=num_classes, model_type=model_type)

    # Train and capture history
    history = model.fit(
        X_train, y_train,
        epochs=30,
        batch_size=32,
        validation_split=0.2,
        class_weight=class_weights,
        verbose=1
    )

    # Plotting training history
    plt.figure(figsize=(14, 6))

    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.legend()

    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

    y_pred = np.argmax(model.predict(X_test), axis=1)
    y_true = np.argmax(y_test, axis=1)  # Fix: convert from one-hot to labels

    labels = le.inverse_transform(np.arange(num_classes))  # class names (strings)

    # Fix: use y_true (not y_test anymore)
    result = evaluate_and_report(y_true, y_pred, name, np.arange(num_classes), labels)
    result["model"] = "BI-LSTM"
    return result

# %% [markdown]
# ## 6. Models

# %%
if __name__ == "__main__":
    dl_final_results = {}

    for n in [10,20,30,40,50]:
        print(f"\nProcessing Top {n} Web Service Categories")
        df = pd.read_csv(f"../data-preprocessing/Pre_Processed_Top_{n}_Web_Services_Categories.csv")

        results = []
        for model_type in ["BI-LSTM"]:
            name = f"{model_type.upper()} Top {n}"
            result = train_dl_model(df, model_type, name)
            results.append(result)
            print(result)
        dl_final_results[n] = results

    # Save all results
    with open("results/dl_final_results.pkl", "wb") as f:
        pickle.dump(dl_final_results, f)
# Out:
# Processing Top 10 Web Service Categories
# Epoch 1/30
# I0000 00:00:1749731552.951584   21322 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13775 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# I0000 00:00:1749731558.239387   21891 cuda_dnn.cc:529] Loaded cuDNN version 90701
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.1687 - loss: 2.3321 - val_accuracy: 0.5445 - val_loss: 1.6718
# Epoch 2/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5023 - loss: 1.4448 - val_accuracy: 0.7264 - val_loss: 1.0092
# Epoch 3/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7253 - loss: 0.8170 - val_accuracy: 0.7450 - val_loss: 0.8872
# Epoch 4/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8400 - loss: 0.5079 - val_accuracy: 0.7477 - val_loss: 0.8257
# Epoch 5/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9148 - loss: 0.2642 - val_accuracy: 0.7543 - val_loss: 0.9014
# Epoch 6/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9569 - loss: 0.1677 - val_accuracy: 0.7689 - val_loss: 0.9198
# Epoch 7/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9743 - loss: 0.1048 - val_accuracy: 0.7703 - val_loss: 1.0260
# Epoch 8/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9799 - loss: 0.0786 - val_accuracy: 0.7410 - val_loss: 1.1484
# Epoch 9/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9796 - loss: 0.0910 - val_accuracy: 0.7570 - val_loss: 1.1237
# Epoch 10/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9880 - loss: 0.0627 - val_accuracy: 0.7556 - val_loss: 1.1410
# Epoch 11/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9866 - loss: 0.0539 - val_accuracy: 0.7477 - val_loss: 1.1431
# Epoch 12/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9763 - loss: 0.0919 - val_accuracy: 0.7676 - val_loss: 1.0669
# Epoch 13/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9922 - loss: 0.0396 - val_accuracy: 0.7716 - val_loss: 1.2163
# Epoch 14/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9906 - loss: 0.0378 - val_accuracy: 0.7410 - val_loss: 1.3124
# Epoch 15/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9845 - loss: 0.0624 - val_accuracy: 0.7610 - val_loss: 1.2726
# Epoch 16/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9913 - loss: 0.0280 - val_accuracy: 0.7570 - val_loss: 1.3037
# Epoch 17/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9900 - loss: 0.0304 - val_accuracy: 0.7357 - val_loss: 1.6149
# Epoch 18/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9891 - loss: 0.0362 - val_accuracy: 0.7556 - val_loss: 1.4688
# Epoch 19/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9860 - loss: 0.0416 - val_accuracy: 0.7371 - val_loss: 1.5115
# Epoch 20/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9888 - loss: 0.0389 - val_accuracy: 0.7503 - val_loss: 1.4694
# Epoch 21/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9957 - loss: 0.0190 - val_accuracy: 0.7424 - val_loss: 1.4684
# Epoch 22/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9950 - loss: 0.0210 - val_accuracy: 0.7450 - val_loss: 1.5639
# Epoch 23/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9949 - loss: 0.0190 - val_accuracy: 0.7596 - val_loss: 1.5633
# Epoch 24/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9946 - loss: 0.0185 - val_accuracy: 0.7357 - val_loss: 1.5179
# Epoch 25/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9804 - loss: 0.0672 - val_accuracy: 0.7583 - val_loss: 1.3378
# Epoch 26/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9894 - loss: 0.0473 - val_accuracy: 0.7424 - val_loss: 1.3726
# Epoch 27/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9949 - loss: 0.0229 - val_accuracy: 0.7583 - val_loss: 1.4274
# Epoch 28/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9950 - loss: 0.0219 - val_accuracy: 0.7517 - val_loss: 1.5654
# Epoch 29/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9962 - loss: 0.0145 - val_accuracy: 0.7663 - val_loss: 1.6797
# Epoch 30/30
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9955 - loss: 0.0117 - val_accuracy: 0.7463 - val_loss: 1.8747
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#
#  BI-LSTM Top 10 Classification Report:
#
#               precision    recall  f1-score   support
#
#   Enterprise       0.73      0.57      0.64        82
#    Financial       0.80      0.81      0.81       138
#   Government       0.77      0.70      0.74        61
#      Mapping       0.76      0.94      0.84        72
#    Messaging       0.77      0.86      0.81       102
#     Payments       0.57      0.86      0.68        92
#       Social       0.69      0.69      0.69        87
#    Telephony       0.67      0.62      0.64        60
#        Tools       0.83      0.62      0.71       154
#    eCommerce       0.84      0.72      0.77        93
#
#     accuracy                           0.74       941
#    macro avg       0.74      0.74      0.73       941
# weighted avg       0.75      0.74      0.74       941
#
# Classification report saved to: DL-Report-BI-LSTM Top 10.csv
# Confusion matrix saved to: charts/DL_confusion_matrix_BI-LSTM_Top_10.png
# {'accuracy': 0.7396386822529224, 'precision': 0.7520366706477004, 'recall': 0.7396386822529224, 'f1_score': 0.7378766693875032, 'model': 'BI-LSTM'}
#
# Processing Top 20 Web Service Categories
# Epoch 1/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.1010 - loss: 3.0169 - val_accuracy: 0.4852 - val_loss: 2.1538
# Epoch 2/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.4038 - loss: 1.9152 - val_accuracy: 0.6272 - val_loss: 1.4668
# Epoch 3/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6346 - loss: 1.1353 - val_accuracy: 0.6751 - val_loss: 1.2024
# Epoch 4/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7575 - loss: 0.7564 - val_accuracy: 0.6925 - val_loss: 1.0833
# Epoch 5/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8275 - loss: 0.5493 - val_accuracy: 0.6760 - val_loss: 1.1263
# Epoch 6/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8661 - loss: 0.3960 - val_accuracy: 0.6908 - val_loss: 1.1738
# Epoch 7/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9158 - loss: 0.2502 - val_accuracy: 0.6864 - val_loss: 1.2506
# Epoch 8/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9313 - loss: 0.2211 - val_accuracy: 0.6882 - val_loss: 1.3011
# Epoch 9/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9432 - loss: 0.1663 - val_accuracy: 0.6951 - val_loss: 1.3467
# Epoch 10/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9604 - loss: 0.1241 - val_accuracy: 0.6760 - val_loss: 1.4511
# Epoch 11/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9658 - loss: 0.1153 - val_accuracy: 0.6864 - val_loss: 1.5237
# Epoch 12/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9735 - loss: 0.0822 - val_accuracy: 0.6899 - val_loss: 1.5639
# Epoch 13/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9691 - loss: 0.0939 - val_accuracy: 0.6751 - val_loss: 1.7044
# Epoch 14/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9670 - loss: 0.1035 - val_accuracy: 0.6681 - val_loss: 1.7312
# Epoch 15/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9761 - loss: 0.0854 - val_accuracy: 0.6864 - val_loss: 1.6680
# Epoch 16/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9822 - loss: 0.0611 - val_accuracy: 0.6690 - val_loss: 1.8267
# Epoch 17/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9795 - loss: 0.0674 - val_accuracy: 0.6786 - val_loss: 1.8162
# Epoch 18/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9691 - loss: 0.0887 - val_accuracy: 0.6655 - val_loss: 1.8941
# Epoch 19/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9849 - loss: 0.0540 - val_accuracy: 0.6855 - val_loss: 1.9417
# Epoch 20/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9877 - loss: 0.0488 - val_accuracy: 0.6733 - val_loss: 2.0993
# Epoch 21/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9860 - loss: 0.0482 - val_accuracy: 0.6542 - val_loss: 2.0361
# Epoch 22/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9738 - loss: 0.0912 - val_accuracy: 0.6725 - val_loss: 1.8517
# Epoch 23/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9827 - loss: 0.0617 - val_accuracy: 0.6733 - val_loss: 2.0790
# Epoch 24/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9847 - loss: 0.0539 - val_accuracy: 0.6812 - val_loss: 2.0661
# Epoch 25/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9854 - loss: 0.0469 - val_accuracy: 0.6638 - val_loss: 2.2341
# Epoch 26/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9873 - loss: 0.0343 - val_accuracy: 0.6838 - val_loss: 2.3906
# Epoch 27/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9793 - loss: 0.0547 - val_accuracy: 0.6882 - val_loss: 2.1383
# Epoch 28/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9953 - loss: 0.0206 - val_accuracy: 0.6733 - val_loss: 2.3417
# Epoch 29/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9876 - loss: 0.0394 - val_accuracy: 0.6873 - val_loss: 2.3300
# Epoch 30/30
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9882 - loss: 0.0420 - val_accuracy: 0.6882 - val_loss: 2.4280
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
#  BI-LSTM Top 20 Classification Report:
#
#                 precision    recall  f1-score   support
#
#    Advertising       0.66      0.69      0.67        45
#          Email       0.92      0.69      0.79        51
#     Enterprise       0.45      0.59      0.51        82
#      Financial       0.81      0.77      0.79       137
#     Government       0.65      0.66      0.65        61
#        Mapping       0.69      0.68      0.69        72
#      Messaging       0.77      0.77      0.77       102
#       Payments       0.68      0.88      0.76        92
#      Reference       0.39      0.18      0.25        50
#        Science       0.74      0.88      0.80        60
#         Search       0.48      0.70      0.57        50
#       Security       0.51      0.62      0.56        50
#         Social       0.74      0.49      0.59        87
#         Sports       0.91      0.89      0.90        46
#      Telephony       0.70      0.53      0.60        60
#          Tools       0.60      0.56      0.58       154
# Transportation       0.72      0.66      0.69        44
#         Travel       0.68      0.88      0.77        49
#          Video       0.87      0.80      0.83        50
#      eCommerce       0.80      0.77      0.79        93
#
#       accuracy                           0.68      1435
#      macro avg       0.69      0.68      0.68      1435
#   weighted avg       0.69      0.68      0.68      1435
#
# Classification report saved to: DL-Report-BI-LSTM Top 20.csv
# Confusion matrix saved to: charts/DL_confusion_matrix_BI-LSTM_Top_20.png
# {'accuracy': 0.6843205574912892, 'precision': 0.6916695975932666, 'recall': 0.6843205574912892, 'f1_score': 0.6808340884912616, 'model': 'BI-LSTM'}
#
# Processing Top 30 Web Service Categories
# Epoch 1/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.0562 - loss: 3.3281 - val_accuracy: 0.2821 - val_loss: 2.8884
# Epoch 2/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.2459 - loss: 2.6811 - val_accuracy: 0.5628 - val_loss: 1.9684
# Epoch 3/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.4945 - loss: 1.7005 - val_accuracy: 0.6164 - val_loss: 1.5479
# Epoch 4/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6256 - loss: 1.1822 - val_accuracy: 0.6396 - val_loss: 1.3968
# Epoch 5/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7208 - loss: 0.8750 - val_accuracy: 0.6474 - val_loss: 1.3801
# Epoch 6/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7878 - loss: 0.6147 - val_accuracy: 0.6312 - val_loss: 1.3953
# Epoch 7/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8314 - loss: 0.5279 - val_accuracy: 0.6446 - val_loss: 1.4404
# Epoch 8/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8776 - loss: 0.3566 - val_accuracy: 0.6241 - val_loss: 1.5432
# Epoch 9/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8915 - loss: 0.3029 - val_accuracy: 0.6453 - val_loss: 1.5433
# Epoch 10/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9055 - loss: 0.2650 - val_accuracy: 0.6312 - val_loss: 1.6617
# Epoch 11/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9269 - loss: 0.2131 - val_accuracy: 0.5994 - val_loss: 2.0092
# Epoch 12/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9279 - loss: 0.2177 - val_accuracy: 0.6276 - val_loss: 1.9120
# Epoch 13/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9481 - loss: 0.1544 - val_accuracy: 0.6312 - val_loss: 2.0518
# Epoch 14/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9502 - loss: 0.1507 - val_accuracy: 0.6368 - val_loss: 1.8641
# Epoch 15/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9546 - loss: 0.1333 - val_accuracy: 0.6347 - val_loss: 2.1508
# Epoch 16/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9658 - loss: 0.1044 - val_accuracy: 0.6298 - val_loss: 2.2380
# Epoch 17/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9690 - loss: 0.0978 - val_accuracy: 0.6227 - val_loss: 2.3039
# Epoch 18/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9675 - loss: 0.1037 - val_accuracy: 0.6276 - val_loss: 2.3516
# Epoch 19/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9685 - loss: 0.0872 - val_accuracy: 0.6319 - val_loss: 2.1290
# Epoch 20/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9647 - loss: 0.1036 - val_accuracy: 0.6185 - val_loss: 2.3959
# Epoch 21/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9610 - loss: 0.1062 - val_accuracy: 0.6192 - val_loss: 2.5226
# Epoch 22/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9749 - loss: 0.0712 - val_accuracy: 0.6368 - val_loss: 2.5002
# Epoch 23/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9708 - loss: 0.0966 - val_accuracy: 0.6276 - val_loss: 2.7348
# Epoch 24/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9726 - loss: 0.0727 - val_accuracy: 0.6269 - val_loss: 2.7250
# Epoch 25/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9687 - loss: 0.0965 - val_accuracy: 0.6248 - val_loss: 2.6521
# Epoch 26/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9780 - loss: 0.0696 - val_accuracy: 0.6178 - val_loss: 3.0299
# Epoch 27/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9805 - loss: 0.0667 - val_accuracy: 0.6312 - val_loss: 2.6134
# Epoch 28/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9764 - loss: 0.0677 - val_accuracy: 0.6340 - val_loss: 2.7614
# Epoch 29/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9783 - loss: 0.0708 - val_accuracy: 0.6248 - val_loss: 2.6867
# Epoch 30/30
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9801 - loss: 0.0621 - val_accuracy: 0.6298 - val_loss: 2.9031
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
#  BI-LSTM Top 30 Classification Report:
#
#                     precision    recall  f1-score   support
#
#        Advertising       0.67      0.69      0.68        45
#            Bitcoin       0.62      0.79      0.70        29
#              Cloud       0.62      0.60      0.61        35
#               Data       0.33      0.36      0.34        28
#           Database       0.33      0.22      0.27        27
#          Education       0.70      0.74      0.72        43
#              Email       0.76      0.73      0.74        51
#         Enterprise       0.60      0.34      0.43        82
#          Financial       0.78      0.72      0.75       137
#              Games       0.85      0.68      0.76        41
#         Government       0.74      0.52      0.62        61
#            Mapping       0.67      0.72      0.69        72
#          Messaging       0.82      0.83      0.83       102
#              Music       0.87      0.89      0.88        38
#              Other       0.12      0.16      0.14        32
#           Payments       0.83      0.76      0.80        92
#             Photos       0.71      0.59      0.65        37
# Project Management       0.61      0.68      0.64        28
#          Reference       0.12      0.24      0.16        50
#            Science       0.88      0.58      0.70        60
#             Search       0.39      0.72      0.50        50
#           Security       0.60      0.50      0.54        50
#             Social       0.55      0.56      0.56        87
#             Sports       0.94      0.74      0.83        46
#          Telephony       0.78      0.60      0.68        60
#              Tools       0.46      0.58      0.52       153
#     Transportation       0.88      0.66      0.75        44
#             Travel       0.81      0.88      0.84        49
#              Video       0.82      0.84      0.83        50
#          eCommerce       0.76      0.69      0.72        93
#
#           accuracy                           0.64      1772
#          macro avg       0.65      0.62      0.63      1772
#       weighted avg       0.67      0.64      0.65      1772
#
# Classification report saved to: DL-Report-BI-LSTM Top 30.csv
# Confusion matrix saved to: charts/DL_confusion_matrix_BI-LSTM_Top_30.png
# {'accuracy': 0.6360045146726863, 'precision': 0.6706222897134395, 'recall': 0.6360045146726863, 'f1_score': 0.6451994900159094, 'model': 'BI-LSTM'}
#
# Processing Top 40 Web Service Categories
# Epoch 1/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.0248 - loss: 3.7455 - val_accuracy: 0.1315 - val_loss: 3.3899
# Epoch 2/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.1520 - loss: 3.1260 - val_accuracy: 0.5118 - val_loss: 2.3230
# Epoch 3/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.3620 - loss: 2.1845 - val_accuracy: 0.5806 - val_loss: 1.7810
# Epoch 4/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5234 - loss: 1.5488 - val_accuracy: 0.6005 - val_loss: 1.6064
# Epoch 5/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6304 - loss: 1.1210 - val_accuracy: 0.6129 - val_loss: 1.5301
# Epoch 6/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7184 - loss: 0.8269 - val_accuracy: 0.6253 - val_loss: 1.5118
# Epoch 7/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7719 - loss: 0.6680 - val_accuracy: 0.6185 - val_loss: 1.5692
# Epoch 8/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8169 - loss: 0.5049 - val_accuracy: 0.6328 - val_loss: 1.6484
# Epoch 9/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8461 - loss: 0.4020 - val_accuracy: 0.6334 - val_loss: 1.7072
# Epoch 10/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8730 - loss: 0.3368 - val_accuracy: 0.6334 - val_loss: 1.8006
# Epoch 11/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9042 - loss: 0.2771 - val_accuracy: 0.6222 - val_loss: 1.9186
# Epoch 12/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9090 - loss: 0.2428 - val_accuracy: 0.6377 - val_loss: 2.0201
# Epoch 13/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9155 - loss: 0.2295 - val_accuracy: 0.6334 - val_loss: 1.9401
# Epoch 14/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9244 - loss: 0.2028 - val_accuracy: 0.6228 - val_loss: 2.0962
# Epoch 15/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9300 - loss: 0.1852 - val_accuracy: 0.6458 - val_loss: 2.1840
# Epoch 16/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9435 - loss: 0.1480 - val_accuracy: 0.6278 - val_loss: 2.3299
# Epoch 17/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9528 - loss: 0.1341 - val_accuracy: 0.6414 - val_loss: 2.3386
# Epoch 18/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9475 - loss: 0.1297 - val_accuracy: 0.6346 - val_loss: 2.3572
# Epoch 19/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9584 - loss: 0.1133 - val_accuracy: 0.6110 - val_loss: 2.5964
# Epoch 20/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9575 - loss: 0.1121 - val_accuracy: 0.6191 - val_loss: 2.4422
# Epoch 21/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9559 - loss: 0.1226 - val_accuracy: 0.6241 - val_loss: 2.6705
# Epoch 22/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9561 - loss: 0.1131 - val_accuracy: 0.6086 - val_loss: 2.7489
# Epoch 23/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9585 - loss: 0.1207 - val_accuracy: 0.6117 - val_loss: 2.6086
# Epoch 24/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9642 - loss: 0.0932 - val_accuracy: 0.6098 - val_loss: 2.7232
# Epoch 25/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9640 - loss: 0.1101 - val_accuracy: 0.6154 - val_loss: 2.9351
# Epoch 26/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9664 - loss: 0.0894 - val_accuracy: 0.6197 - val_loss: 2.8135
# Epoch 27/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9587 - loss: 0.1228 - val_accuracy: 0.6148 - val_loss: 2.9113
# Epoch 28/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9655 - loss: 0.0887 - val_accuracy: 0.6222 - val_loss: 3.0399
# Epoch 29/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9737 - loss: 0.0686 - val_accuracy: 0.6166 - val_loss: 3.0521
# Epoch 30/30
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9735 - loss: 0.0700 - val_accuracy: 0.6166 - val_loss: 3.1071
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
#  BI-LSTM Top 40 Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.66      0.64      0.65        45
#               Analytics       0.33      0.17      0.23        23
# Application Development       0.15      0.24      0.19        25
#                 Backend       0.53      0.37      0.43        27
#                 Banking       0.64      0.73      0.68        22
#                 Bitcoin       0.63      0.59      0.61        29
#                   Cloud       0.44      0.43      0.43        35
#                    Data       0.33      0.32      0.33        28
#                Database       0.21      0.26      0.23        27
#               Education       0.68      0.58      0.63        43
#                   Email       0.64      0.76      0.70        51
#              Enterprise       0.36      0.33      0.34        82
#                  Events       0.71      0.77      0.74        22
#               Financial       0.68      0.61      0.64       137
#                   Games       0.94      0.73      0.82        41
#              Government       0.72      0.48      0.57        61
#      Internet of Things       0.71      0.52      0.60        23
#                 Mapping       0.67      0.68      0.68        72
#                 Medical       0.52      0.64      0.57        22
#               Messaging       0.81      0.72      0.76       102
#                   Music       0.83      0.76      0.79        38
#                   Other       0.10      0.09      0.10        32
#                Payments       0.79      0.64      0.71        92
#                  Photos       0.68      0.81      0.74        37
#      Project Management       0.57      0.57      0.57        28
#               Reference       0.19      0.22      0.20        50
#                 Science       0.67      0.62      0.64        60
#                  Search       0.46      0.52      0.49        50
#                Security       0.43      0.44      0.44        50
#                Shipping       0.83      0.74      0.78        27
#                  Social       0.49      0.51      0.50        86
#                  Sports       0.86      0.83      0.84        46
#                  Stocks       0.88      0.78      0.82        27
#               Telephony       0.62      0.65      0.63        60
#                   Tools       0.42      0.44      0.43       153
#          Transportation       0.62      0.70      0.66        44
#                  Travel       0.67      0.88      0.76        49
#                   Video       0.88      0.56      0.68        50
#                 Weather       0.81      0.85      0.83        26
#               eCommerce       0.52      0.81      0.64        93
#
#                accuracy                           0.58      2015
#               macro avg       0.59      0.57      0.58      2015
#            weighted avg       0.60      0.58      0.58      2015
#
# Classification report saved to: DL-Report-BI-LSTM Top 40.csv
# Confusion matrix saved to: charts/DL_confusion_matrix_BI-LSTM_Top_40.png
# {'accuracy': 0.5821339950372209, 'precision': 0.5979177588999084, 'recall': 0.5821339950372209, 'f1_score': 0.5841876398432554, 'model': 'BI-LSTM'}
#
# Processing Top 50 Web Service Categories
# Epoch 1/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.0300 - loss: 3.9461 - val_accuracy: 0.1141 - val_loss: 3.6704
# Epoch 2/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.1315 - loss: 3.4141 - val_accuracy: 0.4575 - val_loss: 2.5501
# Epoch 3/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.3539 - loss: 2.3693 - val_accuracy: 0.5157 - val_loss: 2.1318
# Epoch 4/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.4948 - loss: 1.7050 - val_accuracy: 0.5305 - val_loss: 1.9020
# Epoch 5/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6056 - loss: 1.2703 - val_accuracy: 0.5436 - val_loss: 1.8170
# Epoch 6/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.6631 - loss: 0.9888 - val_accuracy: 0.5550 - val_loss: 1.7841
# Epoch 7/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7287 - loss: 0.7688 - val_accuracy: 0.5613 - val_loss: 1.8114
# Epoch 8/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7717 - loss: 0.6523 - val_accuracy: 0.5545 - val_loss: 1.8265
# Epoch 9/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8051 - loss: 0.5444 - val_accuracy: 0.5568 - val_loss: 1.8981
# Epoch 10/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8239 - loss: 0.4898 - val_accuracy: 0.5545 - val_loss: 1.9651
# Epoch 11/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8606 - loss: 0.3828 - val_accuracy: 0.5853 - val_loss: 2.0716
# Epoch 12/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.8787 - loss: 0.3183 - val_accuracy: 0.5733 - val_loss: 2.1092
# Epoch 13/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8834 - loss: 0.3148 - val_accuracy: 0.5653 - val_loss: 2.2918
# Epoch 14/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9057 - loss: 0.2591 - val_accuracy: 0.5710 - val_loss: 2.3349
# Epoch 15/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9153 - loss: 0.2221 - val_accuracy: 0.5647 - val_loss: 2.3698
# Epoch 16/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9112 - loss: 0.2500 - val_accuracy: 0.5602 - val_loss: 2.5285
# Epoch 17/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9116 - loss: 0.2248 - val_accuracy: 0.5636 - val_loss: 2.6270
# Epoch 18/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9245 - loss: 0.1965 - val_accuracy: 0.5647 - val_loss: 2.8018
# Epoch 19/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9213 - loss: 0.1971 - val_accuracy: 0.5573 - val_loss: 2.8564
# Epoch 20/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9296 - loss: 0.1826 - val_accuracy: 0.5682 - val_loss: 2.7381
# Epoch 21/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9256 - loss: 0.1857 - val_accuracy: 0.5556 - val_loss: 2.9360
# Epoch 22/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9373 - loss: 0.1753 - val_accuracy: 0.5471 - val_loss: 2.9341
# Epoch 23/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9418 - loss: 0.1614 - val_accuracy: 0.5613 - val_loss: 3.1193
# Epoch 24/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9417 - loss: 0.1472 - val_accuracy: 0.5653 - val_loss: 3.0960
# Epoch 25/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9360 - loss: 0.1631 - val_accuracy: 0.5499 - val_loss: 3.1265
# Epoch 26/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9430 - loss: 0.1387 - val_accuracy: 0.5579 - val_loss: 3.3875
# Epoch 27/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9489 - loss: 0.1344 - val_accuracy: 0.5533 - val_loss: 3.3604
# Epoch 28/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9439 - loss: 0.1437 - val_accuracy: 0.5608 - val_loss: 3.4568
# Epoch 29/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9542 - loss: 0.1137 - val_accuracy: 0.5647 - val_loss: 3.5021
# Epoch 30/30
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9579 - loss: 0.1084 - val_accuracy: 0.5562 - val_loss: 3.3076
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
#  BI-LSTM Top 50 Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.66      0.64      0.65        45
#               Analytics       0.36      0.35      0.36        23
# Application Development       0.37      0.28      0.32        25
#                 Backend       0.50      0.19      0.27        27
#                 Banking       0.67      0.73      0.70        22
#                 Bitcoin       0.74      0.86      0.79        29
#                    Chat       0.50      0.56      0.53        16
#                   Cloud       0.67      0.40      0.50        35
#                    Data       0.45      0.36      0.40        28
#                Database       0.19      0.33      0.24        27
#                 Domains       0.65      0.88      0.75        17
#               Education       0.69      0.79      0.74        43
#                   Email       0.60      0.86      0.71        51
#              Enterprise       0.45      0.50      0.47        82
#           Entertainment       0.45      0.47      0.46        19
#                  Events       0.69      0.41      0.51        22
#            File Sharing       0.75      0.71      0.73        17
#               Financial       0.76      0.57      0.65       137
#                   Games       0.63      0.59      0.61        41
#              Government       0.73      0.57      0.64        61
#                  Images       0.50      0.24      0.32        17
#      Internet of Things       0.78      0.78      0.78        23
#                 Mapping       0.71      0.71      0.71        72
#                   Media       0.56      0.31      0.40        16
#                 Medical       0.75      0.68      0.71        22
#               Messaging       0.78      0.80      0.79       102
#                   Music       0.85      0.74      0.79        38
#           News Services       0.60      0.56      0.58        16
#                  Office       0.27      0.19      0.22        16
#                   Other       0.05      0.09      0.07        32
#                Payments       0.74      0.82      0.77        92
#                  Photos       0.73      0.65      0.69        37
#      Project Management       0.61      0.61      0.61        28
#             Real Estate       0.89      0.73      0.80        22
#               Reference       0.25      0.26      0.25        50
#                 Science       0.70      0.67      0.68        60
#                  Search       0.34      0.68      0.46        50
#                Security       0.46      0.72      0.56        50
#                Shipping       0.76      0.81      0.79        27
#                  Social       0.48      0.61      0.54        87
#                  Sports       0.90      0.57      0.69        46
#                  Stocks       0.91      0.78      0.84        27
#                 Storage       0.46      0.55      0.50        20
#               Telephony       0.71      0.57      0.63        60
#                   Tools       0.39      0.37      0.38       153
#          Transportation       0.71      0.61      0.66        44
#                  Travel       0.70      0.76      0.73        49
#                   Video       0.81      0.60      0.69        50
#                 Weather       0.95      0.81      0.88        26
#               eCommerce       0.70      0.57      0.63        93
#
#                accuracy                           0.59      2192
#               macro avg       0.61      0.58      0.58      2192
#            weighted avg       0.62      0.59      0.60      2192
#
# Classification report saved to: DL-Report-BI-LSTM Top 50.csv
# Confusion matrix saved to: charts/DL_confusion_matrix_BI-LSTM_Top_50.png
# {'accuracy': 0.5916970802919708, 'precision': 0.6184488909377183, 'recall': 0.5916970802919708, 'f1_score': 0.5956400417658837, 'model': 'BI-LSTM'}

# %% [markdown]
# ## 5. Performance and Plots

# %%
model_metrics = {}

for n, results in dl_final_results.items():
    for entry in results:
        model = entry['model'].split('Top')[0].strip()  
        if model not in model_metrics:
            model_metrics[model] = {'n': [], 'accuracy': [], 'precision': [], 'recall': [], 'f1_score': []}
        
        model_metrics[model]['n'].append(n)
        model_metrics[model]['accuracy'].append(entry['accuracy'])
        model_metrics[model]['precision'].append(entry['precision'])
        model_metrics[model]['recall'].append(entry['recall'])
        model_metrics[model]['f1_score'].append(entry['f1_score'])

def plot_metric(metric_name):
    plt.figure(figsize=(10, 5))
    for model, data in model_metrics.items():
        plt.plot(data['n'], data[metric_name], marker='o', label=model)
    plt.title(f'{metric_name.capitalize()} vs Number of Web Service Categories')
    plt.xlabel('Number of  Web Service Categories')
    plt.ylabel(metric_name.capitalize())
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plot_path = f"charts/DL_Model_Performance__{metric_name}.png"
    plt.savefig(plot_path)
    plt.show()

plot_metric('accuracy')
plot_metric('precision')
plot_metric('recall')
plot_metric('f1_score')
