# %% [markdown]
# # Objective : Web Services  Classification
# ## Our goal is to build a baseline model with at least 80% accuracy

# %% [markdown]
# ## 1. Load Python Modules

# %%
# Basic Libraries
import re
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Text Preprocessing
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Feature Extraction
from sklearn.feature_extraction.text import TfidfVectorizer
from sentence_transformers import SentenceTransformer

# Encoding and Scaling
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Model Selection & Evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils import class_weight

# ML Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from tabulate import tabulate
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline

# Ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Reading the Web Services dataset

# %%
input_csv = f"Balanced_Top_50_Web_Services.csv"
df = pd.read_csv(input_csv)
print(df)
print(df["Grouped Category"].nunique())
print(df["Grouped Category"].value_counts())
# Out:
#                                     Service Description  \
# 0     CloudMine is a backend-as-a-service platform t...
# 1     TwitrPix gives users the ability to share phot...
# 2     The Statistical Institute of Catalonia (Idesca...
# 3     With this API, devlopers can write their own p...
# 4     Subsonic is a free music streamer that allows ...
# ...                                                 ...
# 9995  The Haralyzer API allows developers to store r...
# 9996  The Stickybits API enables developers to write...
# 9997  The FIX API has existing software that uses FI...
# 9998  FeeFighters is a comparison shopping website f...
# 9999  The Proximus EnCo Smartliving.io API integrate...
#
#      Service Classification    Grouped Category
# 0                   Backend             Backend
# 1                    Photos              Photos
# 2                Government          Government
# 3                    Photos              Photos
# 4                     Music               Music
# ...                     ...                 ...
# 9995                   Data                Data
# 9996                  Other               Other
# 9997                Bitcoin             Bitcoin
# 9998               Payments            Payments
# 9999     Internet of Things  Internet of Things
#
# [10000 rows x 3 columns]
# 50
# Grouped Category
# Backend                    200
# eCommerce                  200
# News Services              200
# Sports                     200
# Advertising                200
# Security                   200
# Events                     200
# Media                      200
# Search                     200
# Social                     200
# Enterprise                 200
# Video                      200
# Payments                   200
# Photos                     200
# Entertainment              200
# Science                    200
# Images                     200
# Shipping                   200
# Banking                    200
# Internet of Things         200
# Other                      200
# Application Development    200
# Education                  200
# File Sharing               200
# Mapping                    200
# Tools                      200
# Weather                    200
# Project Management         200
# Government                 200
# Music                      200
# Messaging                  200
# Bitcoin                    200
# Reference                  200
# Medical                    200
# Data                       200
# Transportation             200
# Database                   200
# Marketing                  200
# Analytics                  200
# Real Estate                200
# Email                      200
# Chat                       200
# Cloud                      200
# Telephony                  200
# Storage                    200
# Stocks                     200
# Domains                    200
# Financial                  200
# Travel                     200
# Games                      200
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Basic Inspection on given dataset

# %%
def basic_inspection_dataset(table):
    print("Top 5 Records of dataset")
    print(table.head())
    print()
        
    print("Bottom 5 Records of dataset")
    print(table.tail())
    print()
    
    print("Column/features/Variable  - Names of Given dataset")
    print(table.columns)
    print()
    
    print("Shape(rows x columns) - of Given dataset")
    print(table.shape)
    print()
    
    print("Data types - Given Column Names")
    print(table.dtypes)
    print()
    
    print("Summry of dataset")
    print(table.info())
    print()
    
    print("To see the count of null/nan values in columns of dataset")
    print(table.isnull().value_counts())
    print()
    
    print("Dataset Summary ")
    print(table.describe())
    print()
    
basic_inspection_dataset(df)
# Out:
# Top 5 Records of dataset
#                                  Service Description Service Classification  \
# 0  CloudMine is a backend-as-a-service platform t...                Backend
# 1  TwitrPix gives users the ability to share phot...                 Photos
# 2  The Statistical Institute of Catalonia (Idesca...             Government
# 3  With this API, devlopers can write their own p...                 Photos
# 4  Subsonic is a free music streamer that allows ...                  Music
#
#   Grouped Category
# 0          Backend
# 1           Photos
# 2       Government
# 3           Photos
# 4            Music
#
# Bottom 5 Records of dataset
#                                     Service Description  \
# 9995  The Haralyzer API allows developers to store r...
# 9996  The Stickybits API enables developers to write...
# 9997  The FIX API has existing software that uses FI...
# 9998  FeeFighters is a comparison shopping website f...
# 9999  The Proximus EnCo Smartliving.io API integrate...
#
#      Service Classification    Grouped Category
# 9995                   Data                Data
# 9996                  Other               Other
# 9997                Bitcoin             Bitcoin
# 9998               Payments            Payments
# 9999     Internet of Things  Internet of Things
#
# Column/features/Variable  - Names of Given dataset
# Index(['Service Description', 'Service Classification', 'Grouped Category'], dtype='object')
#
# Shape(rows x columns) - of Given dataset
# (10000, 3)
#
# Data types - Given Column Names
# Service Description       object
# Service Classification    object
# Grouped Category          object
# dtype: object
#
# Summry of dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Service Description     9994 non-null   object
#  1   Service Classification  10000 non-null  object
#  2   Grouped Category        10000 non-null  object
# dtypes: object(3)
# memory usage: 234.5+ KB
# None
#
# To see the count of null/nan values in columns of dataset
# Service Description  Service Classification  Grouped Category
# False                False                   False               9994
# True                 False                   False                  6
# Name: count, dtype: int64
#
# Dataset Summary
#                                       Service Description  \
# count                                                9994
# unique                                               6931
# top     The IBM Watson Visual Insights API allows deve...
# freq                                                   12
#
#        Service Classification Grouped Category
# count                   10000            10000
# unique                     50               50
# top                   Backend          Backend
# freq                      200              200

# %% [markdown]
# ## 4. Handling Missing Values

# %%
df.isnull().sum()
# Out:
# Service Description       6
# Service Classification    0
# Grouped Category          0
# dtype: int64

# %% [markdown]
# ## 5. Categorical- UniVariable - Analysis

# %%
class BarPieChartTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df=X.copy()
        # get cat columns 
        cat_cols = df.select_dtypes(include='object').columns
        for cat_name in cat_cols:
            value_counts = df[cat_name].value_counts().reset_index()
            # Rename the columns
            value_counts.columns = ['Class', 'Frequency']

            # Print the result as a table
            print(f"{cat_name} frequency table")
            print(tabulate(value_counts, headers='keys', tablefmt='pretty'))

            # Calculate relative frequency
            total_count = value_counts['Frequency'].sum()
            value_counts['Relative Frequency %'] = round((value_counts['Frequency'] / total_count)*100,2)

            # Print the result as a table
            print(f"{cat_name} Relative frequency table")
            print(tabulate(value_counts, headers='keys', tablefmt='pretty'))

            # Extract the values and index from value counts
            value_counts = df[cat_name].value_counts()
            values = value_counts.values
            labels = value_counts.index

            fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns
            # Create a bar graph
            axs[0].bar(labels, values)
            axs[0].set_title(f'Frequency of {cat_name}')
            axs[0].set_xlabel('Categories')  # Set x-label
            axs[0].set_ylabel('Count')       # Set y-label

            axs[1].pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
            axs[1].set_title(f'Relative Frequency of {cat_name}')
            plt.tight_layout()
            # Show the plot
            plt.show()  
            
pipeline_cat_var = Pipeline([
    ('cat_univaraite_analysis', BarPieChartTransformer())
])

# Fit and transform your data using the pipeline
processed_data = pipeline_cat_var.fit_transform(df[["Service Classification", "Grouped Category"]])
# Out:
# Service Classification frequency table
# +----+-------------------------+-----------+
# |    |          Class          | Frequency |
# +----+-------------------------+-----------+
# | 0  |         Backend         |    200    |
# | 1  |        eCommerce        |    200    |
# | 2  |      News Services      |    200    |
# | 3  |         Sports          |    200    |
# | 4  |       Advertising       |    200    |
# | 5  |        Security         |    200    |
# | 6  |         Events          |    200    |
# | 7  |          Media          |    200    |
# | 8  |         Search          |    200    |
# | 9  |         Social          |    200    |
# | 10 |       Enterprise        |    200    |
# | 11 |          Video          |    200    |
# | 12 |        Payments         |    200    |
# | 13 |         Photos          |    200    |
# | 14 |      Entertainment      |    200    |
# | 15 |         Science         |    200    |
# | 16 |         Images          |    200    |
# | 17 |        Shipping         |    200    |
# | 18 |         Banking         |    200    |
# | 19 |   Internet of Things    |    200    |
# | 20 |          Other          |    200    |
# | 21 | Application Development |    200    |
# | 22 |        Education        |    200    |
# | 23 |      File Sharing       |    200    |
# | 24 |         Mapping         |    200    |
# | 25 |          Tools          |    200    |
# | 26 |         Weather         |    200    |
# | 27 |   Project Management    |    200    |
# | 28 |       Government        |    200    |
# | 29 |          Music          |    200    |
# | 30 |        Messaging        |    200    |
# | 31 |         Bitcoin         |    200    |
# | 32 |        Reference        |    200    |
# | 33 |         Medical         |    200    |
# | 34 |          Data           |    200    |
# | 35 |     Transportation      |    200    |
# | 36 |        Database         |    200    |
# | 37 |        Marketing        |    200    |
# | 38 |        Analytics        |    200    |
# | 39 |       Real Estate       |    200    |
# | 40 |          Email          |    200    |
# | 41 |          Chat           |    200    |
# | 42 |          Cloud          |    200    |
# | 43 |        Telephony        |    200    |
# | 44 |         Storage         |    200    |
# | 45 |         Stocks          |    200    |
# | 46 |         Domains         |    200    |
# | 47 |        Financial        |    200    |
# | 48 |         Travel          |    200    |
# | 49 |          Games          |    200    |
# +----+-------------------------+-----------+
# Service Classification Relative frequency table
# +----+-------------------------+-----------+----------------------+
# |    |          Class          | Frequency | Relative Frequency % |
# +----+-------------------------+-----------+----------------------+
# | 0  |         Backend         |    200    |         2.0          |
# | 1  |        eCommerce        |    200    |         2.0          |
# | 2  |      News Services      |    200    |         2.0          |
# | 3  |         Sports          |    200    |         2.0          |
# | 4  |       Advertising       |    200    |         2.0          |
# | 5  |        Security         |    200    |         2.0          |
# | 6  |         Events          |    200    |         2.0          |
# | 7  |          Media          |    200    |         2.0          |
# | 8  |         Search          |    200    |         2.0          |
# | 9  |         Social          |    200    |         2.0          |
# | 10 |       Enterprise        |    200    |         2.0          |
# | 11 |          Video          |    200    |         2.0          |
# | 12 |        Payments         |    200    |         2.0          |
# | 13 |         Photos          |    200    |         2.0          |
# | 14 |      Entertainment      |    200    |         2.0          |
# | 15 |         Science         |    200    |         2.0          |
# | 16 |         Images          |    200    |         2.0          |
# | 17 |        Shipping         |    200    |         2.0          |
# | 18 |         Banking         |    200    |         2.0          |
# | 19 |   Internet of Things    |    200    |         2.0          |
# | 20 |          Other          |    200    |         2.0          |
# | 21 | Application Development |    200    |         2.0          |
# | 22 |        Education        |    200    |         2.0          |
# | 23 |      File Sharing       |    200    |         2.0          |
# | 24 |         Mapping         |    200    |         2.0          |
# | 25 |          Tools          |    200    |         2.0          |
# | 26 |         Weather         |    200    |         2.0          |
# | 27 |   Project Management    |    200    |         2.0          |
# | 28 |       Government        |    200    |         2.0          |
# | 29 |          Music          |    200    |         2.0          |
# | 30 |        Messaging        |    200    |         2.0          |
# | 31 |         Bitcoin         |    200    |         2.0          |
# | 32 |        Reference        |    200    |         2.0          |
# | 33 |         Medical         |    200    |         2.0          |
# | 34 |          Data           |    200    |         2.0          |
# | 35 |     Transportation      |    200    |         2.0          |
# | 36 |        Database         |    200    |         2.0          |
# | 37 |        Marketing        |    200    |         2.0          |
# | 38 |        Analytics        |    200    |         2.0          |
# | 39 |       Real Estate       |    200    |         2.0          |
# | 40 |          Email          |    200    |         2.0          |
# | 41 |          Chat           |    200    |         2.0          |
# | 42 |          Cloud          |    200    |         2.0          |
# | 43 |        Telephony        |    200    |         2.0          |
# | 44 |         Storage         |    200    |         2.0          |
# | 45 |         Stocks          |    200    |         2.0          |
# | 46 |         Domains         |    200    |         2.0          |
# | 47 |        Financial        |    200    |         2.0          |
# | 48 |         Travel          |    200    |         2.0          |
# | 49 |          Games          |    200    |         2.0          |
# +----+-------------------------+-----------+----------------------+
# Grouped Category frequency table
# +----+-------------------------+-----------+
# |    |          Class          | Frequency |
# +----+-------------------------+-----------+
# | 0  |         Backend         |    200    |
# | 1  |        eCommerce        |    200    |
# | 2  |      News Services      |    200    |
# | 3  |         Sports          |    200    |
# | 4  |       Advertising       |    200    |
# | 5  |        Security         |    200    |
# | 6  |         Events          |    200    |
# | 7  |          Media          |    200    |
# | 8  |         Search          |    200    |
# | 9  |         Social          |    200    |
# | 10 |       Enterprise        |    200    |
# | 11 |          Video          |    200    |
# | 12 |        Payments         |    200    |
# | 13 |         Photos          |    200    |
# | 14 |      Entertainment      |    200    |
# | 15 |         Science         |    200    |
# | 16 |         Images          |    200    |
# | 17 |        Shipping         |    200    |
# | 18 |         Banking         |    200    |
# | 19 |   Internet of Things    |    200    |
# | 20 |          Other          |    200    |
# | 21 | Application Development |    200    |
# | 22 |        Education        |    200    |
# | 23 |      File Sharing       |    200    |
# | 24 |         Mapping         |    200    |
# | 25 |          Tools          |    200    |
# | 26 |         Weather         |    200    |
# | 27 |   Project Management    |    200    |
# | 28 |       Government        |    200    |
# | 29 |          Music          |    200    |
# | 30 |        Messaging        |    200    |
# | 31 |         Bitcoin         |    200    |
# | 32 |        Reference        |    200    |
# | 33 |         Medical         |    200    |
# | 34 |          Data           |    200    |
# | 35 |     Transportation      |    200    |
# | 36 |        Database         |    200    |
# | 37 |        Marketing        |    200    |
# | 38 |        Analytics        |    200    |
# | 39 |       Real Estate       |    200    |
# | 40 |          Email          |    200    |
# | 41 |          Chat           |    200    |
# | 42 |          Cloud          |    200    |
# | 43 |        Telephony        |    200    |
# | 44 |         Storage         |    200    |
# | 45 |         Stocks          |    200    |
# | 46 |         Domains         |    200    |
# | 47 |        Financial        |    200    |
# | 48 |         Travel          |    200    |
# | 49 |          Games          |    200    |
# +----+-------------------------+-----------+
# Grouped Category Relative frequency table
# +----+-------------------------+-----------+----------------------+
# |    |          Class          | Frequency | Relative Frequency % |
# +----+-------------------------+-----------+----------------------+
# | 0  |         Backend         |    200    |         2.0          |
# | 1  |        eCommerce        |    200    |         2.0          |
# | 2  |      News Services      |    200    |         2.0          |
# | 3  |         Sports          |    200    |         2.0          |
# | 4  |       Advertising       |    200    |         2.0          |
# | 5  |        Security         |    200    |         2.0          |
# | 6  |         Events          |    200    |         2.0          |
# | 7  |          Media          |    200    |         2.0          |
# | 8  |         Search          |    200    |         2.0          |
# | 9  |         Social          |    200    |         2.0          |
# | 10 |       Enterprise        |    200    |         2.0          |
# | 11 |          Video          |    200    |         2.0          |
# | 12 |        Payments         |    200    |         2.0          |
# | 13 |         Photos          |    200    |         2.0          |
# | 14 |      Entertainment      |    200    |         2.0          |
# | 15 |         Science         |    200    |         2.0          |
# | 16 |         Images          |    200    |         2.0          |
# | 17 |        Shipping         |    200    |         2.0          |
# | 18 |         Banking         |    200    |         2.0          |
# | 19 |   Internet of Things    |    200    |         2.0          |
# | 20 |          Other          |    200    |         2.0          |
# | 21 | Application Development |    200    |         2.0          |
# | 22 |        Education        |    200    |         2.0          |
# | 23 |      File Sharing       |    200    |         2.0          |
# | 24 |         Mapping         |    200    |         2.0          |
# | 25 |          Tools          |    200    |         2.0          |
# | 26 |         Weather         |    200    |         2.0          |
# | 27 |   Project Management    |    200    |         2.0          |
# | 28 |       Government        |    200    |         2.0          |
# | 29 |          Music          |    200    |         2.0          |
# | 30 |        Messaging        |    200    |         2.0          |
# | 31 |         Bitcoin         |    200    |         2.0          |
# | 32 |        Reference        |    200    |         2.0          |
# | 33 |         Medical         |    200    |         2.0          |
# | 34 |          Data           |    200    |         2.0          |
# | 35 |     Transportation      |    200    |         2.0          |
# | 36 |        Database         |    200    |         2.0          |
# | 37 |        Marketing        |    200    |         2.0          |
# | 38 |        Analytics        |    200    |         2.0          |
# | 39 |       Real Estate       |    200    |         2.0          |
# | 40 |          Email          |    200    |         2.0          |
# | 41 |          Chat           |    200    |         2.0          |
# | 42 |          Cloud          |    200    |         2.0          |
# | 43 |        Telephony        |    200    |         2.0          |
# | 44 |         Storage         |    200    |         2.0          |
# | 45 |         Stocks          |    200    |         2.0          |
# | 46 |         Domains         |    200    |         2.0          |
# | 47 |        Financial        |    200    |         2.0          |
# | 48 |         Travel          |    200    |         2.0          |
# | 49 |          Games          |    200    |         2.0          |
# +----+-------------------------+-----------+----------------------+

# %% [markdown]
# ## 6. Preprocessing Web Service Descriptions

# %%
# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize tools
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = word_tokenize(text)
    filtered_tokens = [word for word in tokens if word not in stop_words]
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in stemmed_tokens]

    return " ".join(lemmatized_tokens)


df['Processed Description'] = df['Service Description'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91956\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91956\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91956\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\91956\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## 7. Feature Extraction from Web Service Descriptions using TF-IDF and Sentence Transformers (all-MiniLM-L6-v2)

# %%
def vectorize_descriptions(service_list, max_features=1000):
    """
    Converts a list of service descriptions into a DataFrame of TF-IDF features.
    Limits to top `max_features` terms by importance across the corpus.
    """
    vectorizer = TfidfVectorizer(max_features=max_features)
    tfidf_matrix = vectorizer.fit_transform(service_list)
    feature_names = vectorizer.get_feature_names_out()
    
    return pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)


def embed_descriptions_with_sbert(services, model_name='all-MiniLM-L6-v2'):
    """
    Converts service descriptions into SBERT embeddings using SentenceTransformer.
    """
    model = SentenceTransformer(model_name)
    embeddings = model.encode(services, show_progress_bar=True)
    
    return pd.DataFrame(embeddings, index=services.index if isinstance(services, pd.Series) else None)

# %%
n=50

tfidf_df = vectorize_descriptions(df['Processed Description'])
tfidf_output_csv = f"Processed_Top_{n}_Web_Services_TFIDF.csv"
tfidf_df.to_csv(tfidf_output_csv, encoding='utf-8', index=False, header=True)
print(f"TF-IDF features saved to: {tfidf_output_csv}")

embedding_df = embed_descriptions_with_sbert(df['Processed Description'])
embedding_output_csv = f"Processed_Top_{n}_Web_Services_SBERT_Embeddings.csv"
embedding_df.to_csv(embedding_output_csv, encoding='utf-8', index=False, header=True)
print(f"SBERT embeddings saved to: {embedding_output_csv}")
# Out:
# TF-IDF features saved to: Processed_Top_50_Web_Services_TFIDF.csv
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# SBERT embeddings saved to: Processed_Top_50_Web_Services_SBERT_Embeddings.csv

# %% [markdown]
# ## 8. Models
#
# ### 8.1 TF-IDF + SBERT

# %% [markdown]
# ## 9. Web Service Classification using Logistic Regression

# %%
lr_model_results = []

# %%
def train_and_report_logistic(X_train, X_test, y_train, y_test, name="Model"):
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    print(f"\n{name} Classification Report:\n")
    print(classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred, labels=np.unique(y_test))
    print("\nConfusion Matrix:\n")

    # Heatmap
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
                xticklabels=np.unique(y_test), 
                yticklabels=np.unique(y_test))
    plt.title(f"Confusion Matrix: {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    return {
        "model": f"LogReg  {name}",
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }
    
for n in [50]:

    tfidf_df = pd.read_csv(f"Processed_Top_{n}_Web_Services_TFIDF.csv")
    sbert_df = pd.read_csv(f"Processed_Top_{n}_Web_Services_SBERT_Embeddings.csv")
    original_df = pd.read_csv(f"Balanced_Top_{n}_Web_Services.csv")
    labels = original_df['Grouped Category'].fillna("Unknown")

    combined_df = pd.concat([tfidf_df, sbert_df], axis=1)


    X_train, X_test, y_train, y_test = train_test_split(combined_df, labels, test_size=0.2, random_state=42)


    result=train_and_report_logistic(X_train_tfidf, X_test_tfidf, y_train, y_test, name=f"TF-IDF with {n} Web Services")
    lr_model_results.append(result)
    result=train_and_report_logistic(X_train_sbert, X_test_sbert, y_train, y_test, name=f"SBERT with {n} Web Services")
    lr_model_results.append(result)
    result=train_and_report_logistic(X_train, X_test, y_train, y_test, name=f"TFIDF + SBERT with {n} Web Services")
    lr_model_results.append(result)
    
    scaler = StandardScaler()
    X_train_sbert_scaled = scaler.fit_transform(X_train_sbert)
    X_test_sbert_scaled = scaler.transform(X_test_sbert)

    X_train_tfidf_scaled = X_train_tfidf  
    X_test_tfidf_scaled = X_test_tfidf

    # Combine scaled features
    X_train_combined = np.hstack([X_train_tfidf_scaled, X_train_sbert_scaled])
    X_test_combined = np.hstack([X_test_tfidf_scaled, X_test_sbert_scaled])
    result=train_and_report_logistic(X_train_sbert_scaled, X_test_sbert_scaled, y_train, y_test, name=f"SBERT(Scaled) with {n} Web Services")
    lr_model_results.append(result)
    result=train_and_report_logistic(X_train_combined, X_test_combined, y_train, y_test, name=f"TFIDF + SBERT (Scaled) with {n} Web Services")
    
    lr_model_results.append(result)
# Out:
# TF-IDF with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.66      0.56      0.61        41
#               Analytics       0.70      0.78      0.74        36
# Application Development       0.50      0.62      0.55        34
#                 Backend       0.61      0.66      0.64        41
#                 Banking       0.83      0.94      0.88        36
#                 Bitcoin       0.90      0.85      0.88        33
#                    Chat       0.95      0.93      0.94        45
#                   Cloud       0.57      0.74      0.64        34
#                    Data       0.51      0.50      0.51        36
#                Database       0.70      0.76      0.73        41
#                 Domains       0.90      0.96      0.92        45
#               Education       0.83      0.71      0.77        49
#                   Email       0.74      0.74      0.74        42
#              Enterprise       0.49      0.38      0.43        50
#           Entertainment       0.65      0.74      0.69        35
#                  Events       0.75      0.85      0.80        39
#            File Sharing       0.87      0.85      0.86        39
#               Financial       0.65      0.46      0.54        37
#                   Games       0.81      0.74      0.77        34
#              Government       0.61      0.72      0.66        46
#                  Images       0.73      0.75      0.74        51
#      Internet of Things       0.82      0.86      0.84        43
#                 Mapping       0.75      0.85      0.80        39
#               Marketing       0.62      0.61      0.62        46
#                   Media       0.71      0.69      0.70        32
#                 Medical       0.94      0.74      0.83        43
#               Messaging       0.67      0.85      0.75        34
#                   Music       0.92      0.82      0.87        40
#           News Services       0.92      0.85      0.88        40
#                   Other       0.67      0.50      0.57        32
#                Payments       0.73      0.73      0.73        41
#                  Photos       0.76      0.88      0.82        48
#      Project Management       0.78      0.74      0.76        39
#             Real Estate       0.95      0.90      0.93        42
#               Reference       0.30      0.29      0.30        41
#                 Science       0.63      0.66      0.64        41
#                  Search       0.62      0.59      0.60        49
#                Security       0.52      0.64      0.57        36
#                Shipping       0.88      0.94      0.91        32
#                  Social       0.53      0.51      0.52        35
#                  Sports       0.97      0.80      0.88        45
#                  Stocks       0.96      1.00      0.98        44
#                 Storage       0.80      0.78      0.79        41
#               Telephony       0.74      0.56      0.64        41
#                   Tools       0.34      0.29      0.32        34
#          Transportation       0.79      0.63      0.70        43
#                  Travel       0.82      0.84      0.83        32
#                   Video       0.79      0.85      0.81        39
#                 Weather       0.89      0.98      0.93        42
#               eCommerce       0.58      0.71      0.64        42
#
#                accuracy                           0.73      2000
#               macro avg       0.73      0.73      0.72      2000
#            weighted avg       0.73      0.73      0.73      2000
#
#
# Confusion Matrix:
# SBERT with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.72      0.63      0.68        41
#               Analytics       0.38      0.50      0.43        36
# Application Development       0.42      0.44      0.43        34
#                 Backend       0.61      0.56      0.58        41
#                 Banking       0.76      0.97      0.85        36
#                 Bitcoin       0.83      0.88      0.85        33
#                    Chat       0.88      0.93      0.90        45
#                   Cloud       0.50      0.71      0.59        34
#                    Data       0.34      0.31      0.32        36
#                Database       0.54      0.34      0.42        41
#                 Domains       0.85      0.91      0.88        45
#               Education       0.80      0.65      0.72        49
#                   Email       0.81      0.81      0.81        42
#              Enterprise       0.45      0.26      0.33        50
#           Entertainment       0.68      0.54      0.60        35
#                  Events       0.71      0.74      0.72        39
#            File Sharing       0.84      0.79      0.82        39
#               Financial       0.55      0.30      0.39        37
#                   Games       0.75      0.79      0.77        34
#              Government       0.62      0.63      0.62        46
#                  Images       0.70      0.65      0.67        51
#      Internet of Things       0.60      0.70      0.65        43
#                 Mapping       0.62      0.92      0.74        39
#               Marketing       0.48      0.43      0.45        46
#                   Media       0.57      0.50      0.53        32
#                 Medical       0.83      0.91      0.87        43
#               Messaging       0.64      0.68      0.66        34
#                   Music       0.82      0.90      0.86        40
#           News Services       0.74      0.80      0.77        40
#                   Other       0.50      0.25      0.33        32
#                Payments       0.68      0.73      0.71        41
#                  Photos       0.76      0.77      0.76        48
#      Project Management       0.71      0.74      0.72        39
#             Real Estate       0.79      0.74      0.77        42
#               Reference       0.41      0.29      0.34        41
#                 Science       0.57      0.61      0.59        41
#                  Search       0.56      0.49      0.52        49
#                Security       0.52      0.61      0.56        36
#                Shipping       0.78      0.97      0.86        32
#                  Social       0.37      0.46      0.41        35
#                  Sports       0.87      0.87      0.87        45
#                  Stocks       0.85      0.89      0.87        44
#                 Storage       0.57      0.51      0.54        41
#               Telephony       0.67      0.68      0.67        41
#                   Tools       0.39      0.21      0.27        34
#          Transportation       0.65      0.77      0.70        43
#                  Travel       0.81      0.81      0.81        32
#                   Video       0.74      0.90      0.81        39
#                 Weather       0.85      0.95      0.90        42
#               eCommerce       0.58      0.69      0.63        42
#
#                accuracy                           0.67      2000
#               macro avg       0.65      0.66      0.65      2000
#            weighted avg       0.66      0.67      0.66      2000
#
#
# Confusion Matrix:
# TFIDF + SBERT with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.76      0.68      0.72        41
#               Analytics       0.67      0.81      0.73        36
# Application Development       0.58      0.62      0.60        34
#                 Backend       0.65      0.76      0.70        41
#                 Banking       0.88      0.97      0.92        36
#                 Bitcoin       0.91      0.91      0.91        33
#                    Chat       0.98      0.98      0.98        45
#                   Cloud       0.58      0.74      0.65        34
#                    Data       0.55      0.47      0.51        36
#                Database       0.76      0.63      0.69        41
#                 Domains       0.91      0.96      0.93        45
#               Education       0.85      0.71      0.78        49
#                   Email       0.87      0.81      0.84        42
#              Enterprise       0.53      0.36      0.43        50
#           Entertainment       0.72      0.83      0.77        35
#                  Events       0.82      0.82      0.82        39
#            File Sharing       0.97      0.92      0.95        39
#               Financial       0.68      0.51      0.58        37
#                   Games       0.88      0.82      0.85        34
#              Government       0.78      0.78      0.78        46
#                  Images       0.84      0.80      0.82        51
#      Internet of Things       0.82      0.84      0.83        43
#                 Mapping       0.76      0.95      0.84        39
#               Marketing       0.73      0.76      0.74        46
#                   Media       0.84      0.81      0.83        32
#                 Medical       0.91      0.91      0.91        43
#               Messaging       0.67      0.76      0.71        34
#                   Music       0.92      0.90      0.91        40
#           News Services       1.00      0.88      0.93        40
#                   Other       0.57      0.41      0.47        32
#                Payments       0.78      0.78      0.78        41
#                  Photos       0.79      0.88      0.83        48
#      Project Management       0.83      0.74      0.78        39
#             Real Estate       0.97      0.90      0.94        42
#               Reference       0.37      0.39      0.38        41
#                 Science       0.61      0.61      0.61        41
#                  Search       0.70      0.63      0.67        49
#                Security       0.53      0.64      0.58        36
#                Shipping       0.84      0.97      0.90        32
#                  Social       0.54      0.63      0.58        35
#                  Sports       0.91      0.87      0.89        45
#                  Stocks       0.94      1.00      0.97        44
#                 Storage       0.83      0.83      0.83        41
#               Telephony       0.74      0.68      0.71        41
#                   Tools       0.43      0.29      0.35        34
#          Transportation       0.71      0.70      0.71        43
#                  Travel       0.77      0.84      0.81        32
#                   Video       0.81      0.90      0.85        39
#                 Weather       0.89      0.98      0.93        42
#               eCommerce       0.58      0.71      0.64        42
#
#                accuracy                           0.76      2000
#               macro avg       0.76      0.76      0.76      2000
#            weighted avg       0.76      0.76      0.76      2000
#
#
# Confusion Matrix:
# SBERT(Scaled) with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.74      0.68      0.71        41
#               Analytics       0.74      0.89      0.81        36
# Application Development       0.76      0.76      0.76        34
#                 Backend       0.84      0.88      0.86        41
#                 Banking       0.89      0.94      0.92        36
#                 Bitcoin       0.94      0.94      0.94        33
#                    Chat       0.94      0.98      0.96        45
#                   Cloud       0.68      0.79      0.73        34
#                    Data       0.70      0.78      0.74        36
#                Database       0.60      0.71      0.65        41
#                 Domains       0.88      0.93      0.90        45
#               Education       0.73      0.67      0.70        49
#                   Email       0.85      0.67      0.75        42
#              Enterprise       0.46      0.34      0.39        50
#           Entertainment       0.79      0.86      0.82        35
#                  Events       0.88      0.90      0.89        39
#            File Sharing       0.87      1.00      0.93        39
#               Financial       0.59      0.51      0.55        37
#                   Games       0.86      0.74      0.79        34
#              Government       0.68      0.50      0.57        46
#                  Images       0.86      0.96      0.91        51
#      Internet of Things       0.83      0.79      0.81        43
#                 Mapping       0.72      0.74      0.73        39
#               Marketing       0.75      0.91      0.82        46
#                   Media       0.77      0.94      0.85        32
#                 Medical       0.89      0.91      0.90        43
#               Messaging       0.51      0.65      0.57        34
#                   Music       0.87      0.85      0.86        40
#           News Services       0.90      0.93      0.91        40
#                   Other       0.50      0.72      0.59        32
#                Payments       0.72      0.68      0.70        41
#                  Photos       0.90      0.92      0.91        48
#      Project Management       0.84      0.92      0.88        39
#             Real Estate       0.83      0.90      0.86        42
#               Reference       0.28      0.27      0.27        41
#                 Science       0.69      0.54      0.60        41
#                  Search       0.60      0.43      0.50        49
#                Security       0.50      0.50      0.50        36
#                Shipping       0.89      0.97      0.93        32
#                  Social       0.42      0.29      0.34        35
#                  Sports       0.97      0.87      0.92        45
#                  Stocks       0.95      0.95      0.95        44
#                 Storage       0.82      0.90      0.86        41
#               Telephony       0.59      0.54      0.56        41
#                   Tools       0.39      0.32      0.35        34
#          Transportation       0.82      0.74      0.78        43
#                  Travel       0.81      0.81      0.81        32
#                   Video       0.86      0.79      0.83        39
#                 Weather       0.83      0.95      0.89        42
#               eCommerce       0.61      0.60      0.60        42
#
#                accuracy                           0.75      2000
#               macro avg       0.75      0.76      0.75      2000
#            weighted avg       0.75      0.75      0.75      2000
#
#
# Confusion Matrix:
# TFIDF + SBERT (Scaled) with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.74      0.68      0.71        41
#               Analytics       0.76      0.89      0.82        36
# Application Development       0.76      0.76      0.76        34
#                 Backend       0.84      0.88      0.86        41
#                 Banking       0.89      0.94      0.92        36
#                 Bitcoin       0.94      0.94      0.94        33
#                    Chat       0.94      0.98      0.96        45
#                   Cloud       0.69      0.79      0.74        34
#                    Data       0.71      0.81      0.75        36
#                Database       0.62      0.71      0.66        41
#                 Domains       0.88      0.93      0.90        45
#               Education       0.73      0.67      0.70        49
#                   Email       0.85      0.67      0.75        42
#              Enterprise       0.47      0.34      0.40        50
#           Entertainment       0.79      0.86      0.82        35
#                  Events       0.88      0.90      0.89        39
#            File Sharing       0.87      1.00      0.93        39
#               Financial       0.59      0.51      0.55        37
#                   Games       0.86      0.74      0.79        34
#              Government       0.70      0.50      0.58        46
#                  Images       0.86      0.96      0.91        51
#      Internet of Things       0.83      0.79      0.81        43
#                 Mapping       0.75      0.77      0.76        39
#               Marketing       0.76      0.91      0.83        46
#                   Media       0.79      0.94      0.86        32
#                 Medical       0.89      0.91      0.90        43
#               Messaging       0.52      0.65      0.58        34
#                   Music       0.87      0.85      0.86        40
#           News Services       0.90      0.93      0.91        40
#                   Other       0.50      0.72      0.59        32
#                Payments       0.72      0.68      0.70        41
#                  Photos       0.90      0.92      0.91        48
#      Project Management       0.84      0.92      0.88        39
#             Real Estate       0.83      0.90      0.86        42
#               Reference       0.26      0.27      0.26        41
#                 Science       0.68      0.51      0.58        41
#                  Search       0.62      0.43      0.51        49
#                Security       0.50      0.50      0.50        36
#                Shipping       0.86      0.97      0.91        32
#                  Social       0.41      0.31      0.35        35
#                  Sports       0.97      0.87      0.92        45
#                  Stocks       0.95      0.95      0.95        44
#                 Storage       0.84      0.90      0.87        41
#               Telephony       0.58      0.54      0.56        41
#                   Tools       0.42      0.32      0.37        34
#          Transportation       0.82      0.72      0.77        43
#                  Travel       0.84      0.81      0.83        32
#                   Video       0.86      0.82      0.84        39
#                 Weather       0.82      0.98      0.89        42
#               eCommerce       0.59      0.62      0.60        42
#
#                accuracy                           0.76      2000
#               macro avg       0.75      0.76      0.75      2000
#            weighted avg       0.75      0.76      0.75      2000
#
#
# Confusion Matrix:

# %% [markdown]
# ### 9.1 Web Service Classification using Logistic Regression - Summary

# %%
results_df = pd.DataFrame(lr_model_results)
print(results_df)
df_plot = results_df.set_index('model')
df_plot.plot(kind='bar', figsize=(12, 6))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')
plt.ylim(0.7, 0.95)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
#                                                model  accuracy  precision  \
# 0    LogisticRegression  TF-IDF with 50 Web Services    0.7275   0.730765
# 1     LogisticRegression  SBERT with 50 Web Services    0.6650   0.657351
# 2  LogisticRegression  TFIDF + SBERT with 50 Web ...    0.7635   0.763657
# 3  LogisticRegression  SBERT(Scaled) with 50 Web ...    0.7545   0.749648
# 4  LogisticRegression  TFIDF + SBERT (Scaled) wit...    0.7565   0.752347
#
#    recall  f1_score
# 0  0.7275  0.725825
# 1  0.6650  0.655140
# 2  0.7635  0.760546
# 3  0.7545  0.748555
# 4  0.7565  0.750796

# %% [markdown]
# ## 10.  Web Service Classification using Random Forest

# %%
rf_model_results = []

# %%
def train_and_report_random_forest(X_train, X_test, y_train, y_test, name="Model"):
    # Compute class weights
    classes = np.unique(y_train)
    weights = class_weight.compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights_dict = dict(zip(classes, weights))

    # Train model with class weights
    model = RandomForestClassifier(n_estimators=200, class_weight=class_weights_dict, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(f"\n {name} Classification Report:\n")
    print(classification_report(y_test, y_pred))
    
    cm = confusion_matrix(y_test, y_pred, labels=np.unique(y_test))
    print("\nConfusion Matrix:\n")
    # Heatmap
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
                xticklabels=np.unique(y_test), 
                yticklabels=np.unique(y_test))
    plt.title(f"Confusion Matrix: {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    return {
        "model": f"RandomForestClassifier  {name}",
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }

for n in [50]:

    tfidf_df = pd.read_csv(f"Processed_Top_{n}_Web_Services_TFIDF.csv")
    sbert_df = pd.read_csv(f"Processed_Top_{n}_Web_Services_SBERT_Embeddings.csv")
    original_df = pd.read_csv(f"Balanced_Top_{n}_Web_Services.csv")
    labels = original_df['Grouped Category'].fillna("Unknown")

    combined_df = pd.concat([tfidf_df, sbert_df], axis=1)


    X_train, X_test, y_train, y_test = train_test_split(combined_df, labels, test_size=0.2, random_state=42)
    X_train_tfidf, X_test_tfidf, y_train, y_test = train_test_split(tfidf_df, labels, test_size=0.2, random_state=42)
    X_train_sbert, X_test_sbert, _, _ = train_test_split(sbert_df, labels, test_size=0.2, random_state=42)


    result = train_and_report_random_forest(X_train_tfidf, X_test_tfidf, y_train, y_test, name=f"TF-IDF with {n} Web Services")
    rf_model_results.append(result)
    result = train_and_report_random_forest(X_train_sbert, X_test_sbert, y_train, y_test, name=f"SBERT with {n} Web Services")
    rf_model_results.append(result)
    result = train_and_report_random_forest(X_train, X_test, y_train, y_test, name=f"TFIDF + SBERT with {n} Web Services")
    rf_model_results.append(result)
    # Standardize SBERT features
    scaler = StandardScaler()
    X_train_sbert_scaled = scaler.fit_transform(X_train_sbert)
    X_test_sbert_scaled = scaler.transform(X_test_sbert)

    X_train_tfidf_scaled = X_train_tfidf  
    X_test_tfidf_scaled = X_test_tfidf

    # Combine scaled features
    X_train_combined = np.hstack([X_train_tfidf_scaled, X_train_sbert_scaled])
    X_test_combined = np.hstack([X_test_tfidf_scaled, X_test_sbert_scaled])

    # Run 
    result = train_and_report_random_forest(X_train_sbert_scaled, X_test_sbert_scaled, y_train, y_test, name=f"SBERT(Scaled) with {n}  Web Services")
    rf_model_results.append(result)
    result = train_and_report_random_forest(X_train_combined, X_test_combined, y_train, y_test, name=f"TFIDF + SBERT(Scaled) with {n} Web Services")
    rf_model_results.append(result)
# Out:
#  TF-IDF with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.70      0.63      0.67        41
#               Analytics       0.76      0.86      0.81        36
# Application Development       0.87      0.79      0.83        34
#                 Backend       0.84      0.88      0.86        41
#                 Banking       0.75      1.00      0.86        36
#                 Bitcoin       0.82      0.94      0.87        33
#                    Chat       0.96      1.00      0.98        45
#                   Cloud       0.64      0.94      0.76        34
#                    Data       0.83      0.81      0.82        36
#                Database       0.80      0.78      0.79        41
#                 Domains       0.85      1.00      0.92        45
#               Education       0.78      0.71      0.74        49
#                   Email       0.88      0.69      0.77        42
#              Enterprise       0.42      0.20      0.27        50
#           Entertainment       0.91      0.91      0.91        35
#                  Events       0.90      0.92      0.91        39
#            File Sharing       0.95      1.00      0.97        39
#               Financial       0.64      0.49      0.55        37
#                   Games       0.74      0.76      0.75        34
#              Government       0.62      0.57      0.59        46
#                  Images       0.92      0.90      0.91        51
#      Internet of Things       0.72      0.88      0.79        43
#                 Mapping       0.74      0.74      0.74        39
#               Marketing       0.78      0.87      0.82        46
#                   Media       0.94      0.91      0.92        32
#                 Medical       0.80      0.91      0.85        43
#               Messaging       0.63      0.85      0.72        34
#                   Music       0.95      0.93      0.94        40
#           News Services       0.95      0.93      0.94        40
#                   Other       0.74      0.72      0.73        32
#                Payments       0.83      0.71      0.76        41
#                  Photos       0.79      0.94      0.86        48
#      Project Management       0.67      0.79      0.73        39
#             Real Estate       0.91      0.95      0.93        42
#               Reference       0.42      0.27      0.33        41
#                 Science       0.61      0.54      0.57        41
#                  Search       0.65      0.53      0.58        49
#                Security       0.52      0.42      0.46        36
#                Shipping       0.71      1.00      0.83        32
#                  Social       0.49      0.49      0.49        35
#                  Sports       0.89      0.73      0.80        45
#                  Stocks       0.92      1.00      0.96        44
#                 Storage       0.83      0.98      0.90        41
#               Telephony       0.65      0.54      0.59        41
#                   Tools       0.21      0.21      0.21        34
#          Transportation       0.87      0.63      0.73        43
#                  Travel       0.75      0.84      0.79        32
#                   Video       0.76      0.82      0.79        39
#                 Weather       0.81      1.00      0.89        42
#               eCommerce       0.75      0.57      0.65        42
#
#                accuracy                           0.77      2000
#               macro avg       0.76      0.77      0.76      2000
#            weighted avg       0.76      0.77      0.76      2000
#
#
# Confusion Matrix:
#  SBERT with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.70      0.68      0.69        41
#               Analytics       0.78      0.89      0.83        36
# Application Development       0.84      0.79      0.82        34
#                 Backend       0.79      0.93      0.85        41
#                 Banking       0.85      0.94      0.89        36
#                 Bitcoin       0.83      0.91      0.87        33
#                    Chat       0.93      0.96      0.95        45
#                   Cloud       0.58      0.85      0.69        34
#                    Data       0.88      0.81      0.84        36
#                Database       0.91      0.71      0.79        41
#                 Domains       0.86      0.93      0.89        45
#               Education       0.76      0.57      0.65        49
#                   Email       0.78      0.86      0.82        42
#              Enterprise       0.53      0.32      0.40        50
#           Entertainment       1.00      0.86      0.92        35
#                  Events       0.87      0.87      0.87        39
#            File Sharing       0.97      1.00      0.99        39
#               Financial       0.52      0.32      0.40        37
#                   Games       0.77      0.79      0.78        34
#              Government       0.56      0.59      0.57        46
#                  Images       0.94      0.92      0.93        51
#      Internet of Things       0.86      0.86      0.86        43
#                 Mapping       0.68      0.92      0.78        39
#               Marketing       0.98      0.87      0.92        46
#                   Media       0.97      0.91      0.94        32
#                 Medical       0.87      0.95      0.91        43
#               Messaging       0.52      0.65      0.58        34
#                   Music       0.88      0.90      0.89        40
#           News Services       0.95      0.88      0.91        40
#                   Other       0.96      0.72      0.82        32
#                Payments       0.59      0.83      0.69        41
#                  Photos       0.83      0.94      0.88        48
#      Project Management       0.79      0.85      0.81        39
#             Real Estate       0.97      0.88      0.93        42
#               Reference       0.31      0.27      0.29        41
#                 Science       0.60      0.71      0.65        41
#                  Search       0.66      0.47      0.55        49
#                Security       0.56      0.53      0.54        36
#                Shipping       0.73      1.00      0.84        32
#                  Social       0.55      0.51      0.53        35
#                  Sports       0.95      0.84      0.89        45
#                  Stocks       0.91      0.95      0.93        44
#                 Storage       0.93      0.90      0.91        41
#               Telephony       0.63      0.63      0.63        41
#                   Tools       0.45      0.15      0.22        34
#          Transportation       0.75      0.70      0.72        43
#                  Travel       0.73      0.84      0.78        32
#                   Video       0.69      0.92      0.79        39
#                 Weather       0.85      0.98      0.91        42
#               eCommerce       0.63      0.62      0.63        42
#
#                accuracy                           0.77      2000
#               macro avg       0.77      0.77      0.76      2000
#            weighted avg       0.77      0.77      0.76      2000
#
#
# Confusion Matrix:
#  TFIDF + SBERT with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.80      0.68      0.74        41
#               Analytics       0.80      0.92      0.86        36
# Application Development       0.83      0.74      0.78        34
#                 Backend       0.92      0.88      0.90        41
#                 Banking       0.78      1.00      0.88        36
#                 Bitcoin       0.86      0.97      0.91        33
#                    Chat       0.96      1.00      0.98        45
#                   Cloud       0.58      0.94      0.72        34
#                    Data       0.88      0.83      0.86        36
#                Database       0.97      0.78      0.86        41
#                 Domains       0.83      1.00      0.91        45
#               Education       0.80      0.73      0.77        49
#                   Email       0.84      0.76      0.80        42
#              Enterprise       0.57      0.24      0.34        50
#           Entertainment       0.86      0.89      0.87        35
#                  Events       0.92      0.90      0.91        39
#            File Sharing       0.93      1.00      0.96        39
#               Financial       0.59      0.43      0.50        37
#                   Games       0.84      0.79      0.82        34
#              Government       0.65      0.70      0.67        46
#                  Images       0.91      0.96      0.93        51
#      Internet of Things       0.78      0.81      0.80        43
#                 Mapping       0.69      0.87      0.77        39
#               Marketing       0.87      0.87      0.87        46
#                   Media       0.94      0.94      0.94        32
#                 Medical       0.91      0.95      0.93        43
#               Messaging       0.57      0.82      0.67        34
#                   Music       0.90      0.95      0.93        40
#           News Services       0.95      0.93      0.94        40
#                   Other       0.88      0.72      0.79        32
#                Payments       0.75      0.73      0.74        41
#                  Photos       0.87      0.98      0.92        48
#      Project Management       0.71      0.87      0.78        39
#             Real Estate       0.88      0.90      0.89        42
#               Reference       0.30      0.20      0.24        41
#                 Science       0.60      0.51      0.55        41
#                  Search       0.80      0.57      0.67        49
#                Security       0.50      0.47      0.49        36
#                Shipping       0.73      1.00      0.84        32
#                  Social       0.53      0.54      0.54        35
#                  Sports       0.95      0.87      0.91        45
#                  Stocks       0.93      0.98      0.96        44
#                 Storage       0.90      0.93      0.92        41
#               Telephony       0.71      0.66      0.68        41
#                   Tools       0.35      0.18      0.24        34
#          Transportation       0.78      0.65      0.71        43
#                  Travel       0.76      0.91      0.83        32
#                   Video       0.76      0.90      0.82        39
#                 Weather       0.84      1.00      0.91        42
#               eCommerce       0.57      0.60      0.58        42
#
#                accuracy                           0.79      2000
#               macro avg       0.78      0.79      0.78      2000
#            weighted avg       0.78      0.79      0.78      2000
#
#
# Confusion Matrix:
#  SBERT(Scaled) with 50  Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.66      0.66      0.66        41
#               Analytics       0.80      0.92      0.86        36
# Application Development       0.93      0.74      0.82        34
#                 Backend       0.87      0.98      0.92        41
#                 Banking       0.85      0.94      0.89        36
#                 Bitcoin       0.88      0.91      0.90        33
#                    Chat       0.93      0.96      0.95        45
#                   Cloud       0.68      0.94      0.79        34
#                    Data       0.86      0.83      0.85        36
#                Database       0.97      0.73      0.83        41
#                 Domains       0.87      1.00      0.93        45
#               Education       0.66      0.63      0.65        49
#                   Email       0.80      0.83      0.81        42
#              Enterprise       0.45      0.26      0.33        50
#           Entertainment       0.94      0.83      0.88        35
#                  Events       0.88      0.90      0.89        39
#            File Sharing       0.95      1.00      0.97        39
#               Financial       0.57      0.43      0.49        37
#                   Games       0.74      0.74      0.74        34
#              Government       0.47      0.61      0.53        46
#                  Images       0.94      0.94      0.94        51
#      Internet of Things       0.85      0.81      0.83        43
#                 Mapping       0.70      0.90      0.79        39
#               Marketing       0.95      0.91      0.93        46
#                   Media       1.00      0.91      0.95        32
#                 Medical       0.85      0.93      0.89        43
#               Messaging       0.47      0.59      0.52        34
#                   Music       0.90      0.95      0.93        40
#           News Services       0.88      0.90      0.89        40
#                   Other       0.88      0.72      0.79        32
#                Payments       0.53      0.78      0.63        41
#                  Photos       0.84      0.96      0.89        48
#      Project Management       0.82      0.82      0.82        39
#             Real Estate       1.00      0.83      0.91        42
#               Reference       0.28      0.17      0.21        41
#                 Science       0.61      0.56      0.58        41
#                  Search       0.52      0.47      0.49        49
#                Security       0.56      0.39      0.46        36
#                Shipping       0.76      1.00      0.86        32
#                  Social       0.59      0.49      0.53        35
#                  Sports       0.91      0.87      0.89        45
#                  Stocks       0.93      0.93      0.93        44
#                 Storage       0.95      0.95      0.95        41
#               Telephony       0.58      0.68      0.63        41
#                   Tools       0.67      0.24      0.35        34
#          Transportation       0.74      0.60      0.67        43
#                  Travel       0.76      0.81      0.79        32
#                   Video       0.67      0.90      0.77        39
#                 Weather       0.87      0.95      0.91        42
#               eCommerce       0.52      0.57      0.55        42
#
#                accuracy                           0.77      2000
#               macro avg       0.77      0.77      0.76      2000
#            weighted avg       0.76      0.77      0.76      2000
#
#
# Confusion Matrix:
#  TFIDF + SBERT(Scaled) with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.76      0.68      0.72        41
#               Analytics       0.87      0.92      0.89        36
# Application Development       0.87      0.76      0.81        34
#                 Backend       0.81      0.85      0.83        41
#                 Banking       0.73      1.00      0.85        36
#                 Bitcoin       0.84      0.94      0.89        33
#                    Chat       0.96      1.00      0.98        45
#                   Cloud       0.63      0.94      0.75        34
#                    Data       0.85      0.81      0.83        36
#                Database       0.97      0.73      0.83        41
#                 Domains       0.87      1.00      0.93        45
#               Education       0.76      0.71      0.74        49
#                   Email       0.87      0.79      0.82        42
#              Enterprise       0.40      0.16      0.23        50
#           Entertainment       0.91      0.91      0.91        35
#                  Events       0.85      0.90      0.88        39
#            File Sharing       0.95      1.00      0.97        39
#               Financial       0.59      0.46      0.52        37
#                   Games       0.84      0.79      0.82        34
#              Government       0.59      0.63      0.61        46
#                  Images       0.87      0.94      0.91        51
#      Internet of Things       0.72      0.88      0.79        43
#                 Mapping       0.68      0.87      0.76        39
#               Marketing       0.89      0.87      0.88        46
#                   Media       0.94      0.91      0.92        32
#                 Medical       0.87      0.95      0.91        43
#               Messaging       0.60      0.88      0.71        34
#                   Music       0.90      0.90      0.90        40
#           News Services       0.95      0.90      0.92        40
#                   Other       0.89      0.75      0.81        32
#                Payments       0.76      0.71      0.73        41
#                  Photos       0.88      0.94      0.91        48
#      Project Management       0.75      0.85      0.80        39
#             Real Estate       0.86      0.90      0.88        42
#               Reference       0.33      0.24      0.28        41
#                 Science       0.55      0.54      0.54        41
#                  Search       0.57      0.49      0.53        49
#                Security       0.57      0.47      0.52        36
#                Shipping       0.73      1.00      0.84        32
#                  Social       0.61      0.54      0.58        35
#                  Sports       0.95      0.82      0.88        45
#                  Stocks       0.96      0.98      0.97        44
#                 Storage       0.89      1.00      0.94        41
#               Telephony       0.76      0.63      0.69        41
#                   Tools       0.44      0.21      0.28        34
#          Transportation       0.72      0.65      0.68        43
#                  Travel       0.74      0.81      0.78        32
#                   Video       0.77      0.92      0.84        39
#                 Weather       0.84      0.98      0.90        42
#               eCommerce       0.62      0.60      0.61        42
#
#                accuracy                           0.78      2000
#               macro avg       0.77      0.78      0.77      2000
#            weighted avg       0.77      0.78      0.77      2000
#
#
# Confusion Matrix:

# %% [markdown]
# ### 10.1  Web Service Classification using Random Forest - Summary

# %%
results_df = pd.DataFrame(rf_model_results)
print(results_df)
df_plot = results_df.set_index('model')
df_plot.plot(kind='bar', figsize=(12, 6))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')
plt.ylim(0.7, 0.95)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
#                                                model  accuracy  precision  \
# 0  RandomForestClassifier  TF-IDF with 50 Web Ser...    0.7670   0.759564
# 1  RandomForestClassifier  SBERT with 50 Web Serv...    0.7725   0.770878
# 2  RandomForestClassifier  TFIDF + SBERT with 50 ...    0.7875   0.781136
# 3  RandomForestClassifier  SBERT(Scaled) with 50 ...    0.7665   0.764510
# 4  RandomForestClassifier  TFIDF + SBERT(Scaled) ...    0.7800   0.770788
#
#    recall  f1_score
# 0  0.7670  0.757237
# 1  0.7725  0.764863
# 2  0.7875  0.777438
# 3  0.7665  0.758588
# 4  0.7800  0.769155

# %% [markdown]
# ## 11. Web Service Classification using XGBoost

# %%
xg_model_results = []

# %%
# Label encoder
label_encoder = LabelEncoder()

def train_and_report_xgboost(X_train, X_test, y_train_text, y_test_text, name="Model"):
    # Encode class labels
    y_train = label_encoder.fit_transform(y_train_text)
    y_test = label_encoder.transform(y_test_text)

    # Compute class weights
    classes = np.unique(y_train)
    weights = class_weight.compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights_dict = dict(zip(classes, weights))
    sample_weights = np.array([class_weights_dict[label] for label in y_train])

    # Train model
    model = XGBClassifier(n_estimators=200, random_state=42, use_label_encoder=False, eval_metric='mlogloss')
    model.fit(X_train, y_train, sample_weight=sample_weights)
    y_pred = model.predict(X_test)

    # Decode labels for reporting
    y_test_labels = label_encoder.inverse_transform(y_test)
    y_pred_labels = label_encoder.inverse_transform(y_pred)

    print(f"\n{name} Classification Report:\n")
    print(classification_report(y_test_labels, y_pred_labels))
    cm = confusion_matrix(y_test, y_pred, labels=np.unique(y_test))
    print("\nConfusion Matrix:\n")
    # Heatmap
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
                xticklabels=np.unique(y_test), 
                yticklabels=np.unique(y_test))
    plt.title(f"Confusion Matrix: {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    return {
        "model": f"XGBClassifier  {name}",
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }


for n in [50]:

    tfidf_df = pd.read_csv(f"Processed_Top_{n}_Web_Services_TFIDF.csv")
    sbert_df = pd.read_csv(f"Processed_Top_{n}_Web_Services_SBERT_Embeddings.csv")
    original_df = pd.read_csv(f"Balanced_Top_{n}_Web_Services.csv")
    labels = original_df['Grouped Category'].fillna("Unknown")

    combined_df = pd.concat([tfidf_df, sbert_df], axis=1)


    X_train, X_test, y_train, y_test = train_test_split(combined_df, labels, test_size=0.2, random_state=42)
    X_train_tfidf, X_test_tfidf, y_train, y_test = train_test_split(tfidf_df, labels, test_size=0.2, random_state=42)
    X_train_sbert, X_test_sbert, _, _ = train_test_split(sbert_df, labels, test_size=0.2, random_state=42)


    result = train_and_report_xgboost(X_train_tfidf, X_test_tfidf, y_train, y_test, name=f"TF-IDF with {n} Web Services")
    xg_model_results.append(result)
    result = train_and_report_xgboost(X_train_sbert, X_test_sbert, y_train, y_test, name=f"SBERT with {n} Web Services")
    xg_model_results.append(result)
    result = train_and_report_xgboost(X_train, X_test, y_train, y_test, name=f"TFIDF + SBERT with {n} Web Services")
    xg_model_results.append(result)
    
    # Standardize SBERT features
    scaler = StandardScaler()
    X_train_sbert_scaled = scaler.fit_transform(X_train_sbert)
    X_test_sbert_scaled = scaler.transform(X_test_sbert)

    X_train_tfidf_scaled = X_train_tfidf  
    X_test_tfidf_scaled = X_test_tfidf

    # Combine scaled features
    X_train_combined = np.hstack([X_train_tfidf_scaled, X_train_sbert_scaled])
    X_test_combined = np.hstack([X_test_tfidf_scaled, X_test_sbert_scaled])

    # Run reports
    result = train_and_report_xgboost(X_train_sbert_scaled, X_test_sbert_scaled, y_train, y_test, name=f"SBERT (Scaled) with {n} Web Services")
    xg_model_results.append(result)

    result = train_and_report_xgboost(X_train_combined, X_test_combined, y_train, y_test, name=f"TFIDF + SBERT (Scaled) with {n} Web Services")
    xg_model_results.append(result)
# Out:
# TF-IDF with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.66      0.66      0.66        41
#               Analytics       0.76      0.89      0.82        36
# Application Development       0.70      0.82      0.76        34
#                 Backend       0.86      0.88      0.87        41
#                 Banking       0.88      0.97      0.92        36
#                 Bitcoin       0.91      0.97      0.94        33
#                    Chat       1.00      0.98      0.99        45
#                   Cloud       0.77      0.88      0.82        34
#                    Data       0.69      0.81      0.74        36
#                Database       0.80      0.78      0.79        41
#                 Domains       0.90      1.00      0.95        45
#               Education       0.76      0.71      0.74        49
#                   Email       0.83      0.71      0.77        42
#              Enterprise       0.34      0.20      0.25        50
#           Entertainment       0.80      0.91      0.85        35
#                  Events       0.80      0.92      0.86        39
#            File Sharing       0.93      1.00      0.96        39
#               Financial       0.61      0.46      0.52        37
#                   Games       0.74      0.74      0.74        34
#              Government       0.64      0.59      0.61        46
#                  Images       0.89      0.94      0.91        51
#      Internet of Things       0.78      0.88      0.83        43
#                 Mapping       0.78      0.79      0.78        39
#               Marketing       0.87      0.87      0.87        46
#                   Media       0.83      0.91      0.87        32
#                 Medical       0.84      0.88      0.86        43
#               Messaging       0.62      0.85      0.72        34
#                   Music       0.97      0.85      0.91        40
#           News Services       0.97      0.88      0.92        40
#                   Other       0.65      0.75      0.70        32
#                Payments       0.82      0.76      0.78        41
#                  Photos       0.88      0.92      0.90        48
#      Project Management       0.85      0.85      0.85        39
#             Real Estate       0.91      0.98      0.94        42
#               Reference       0.24      0.20      0.22        41
#                 Science       0.51      0.54      0.52        41
#                  Search       0.55      0.43      0.48        49
#                Security       0.50      0.44      0.47        36
#                Shipping       0.78      1.00      0.88        32
#                  Social       0.48      0.43      0.45        35
#                  Sports       0.89      0.73      0.80        45
#                  Stocks       0.96      0.98      0.97        44
#                 Storage       0.91      0.95      0.93        41
#               Telephony       0.67      0.44      0.53        41
#                   Tools       0.21      0.26      0.24        34
#          Transportation       0.84      0.63      0.72        43
#                  Travel       0.70      0.72      0.71        32
#                   Video       0.68      0.69      0.68        39
#                 Weather       0.87      0.98      0.92        42
#               eCommerce       0.63      0.64      0.64        42
#
#                accuracy                           0.76      2000
#               macro avg       0.75      0.76      0.75      2000
#            weighted avg       0.75      0.76      0.75      2000
#
#
# Confusion Matrix:
# SBERT with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.84      0.66      0.74        41
#               Analytics       0.66      0.92      0.77        36
# Application Development       0.73      0.79      0.76        34
#                 Backend       0.74      0.95      0.83        41
#                 Banking       0.88      0.97      0.92        36
#                 Bitcoin       0.88      0.88      0.88        33
#                    Chat       0.96      1.00      0.98        45
#                   Cloud       0.70      0.76      0.73        34
#                    Data       0.73      0.83      0.78        36
#                Database       0.75      0.73      0.74        41
#                 Domains       0.76      0.93      0.84        45
#               Education       0.68      0.53      0.60        49
#                   Email       0.88      0.69      0.77        42
#              Enterprise       0.39      0.28      0.33        50
#           Entertainment       0.94      0.86      0.90        35
#                  Events       0.88      0.90      0.89        39
#            File Sharing       0.93      1.00      0.96        39
#               Financial       0.65      0.35      0.46        37
#                   Games       0.93      0.76      0.84        34
#              Government       0.50      0.54      0.52        46
#                  Images       0.88      0.88      0.88        51
#      Internet of Things       0.70      0.74      0.72        43
#                 Mapping       0.76      0.82      0.79        39
#               Marketing       0.83      0.87      0.85        46
#                   Media       0.91      0.94      0.92        32
#                 Medical       0.93      0.93      0.93        43
#               Messaging       0.61      0.68      0.64        34
#                   Music       0.97      0.90      0.94        40
#           News Services       0.95      0.88      0.91        40
#                   Other       0.66      0.72      0.69        32
#                Payments       0.75      0.66      0.70        41
#                  Photos       0.85      0.92      0.88        48
#      Project Management       0.80      0.82      0.81        39
#             Real Estate       0.82      0.86      0.84        42
#               Reference       0.39      0.32      0.35        41
#                 Science       0.54      0.46      0.50        41
#                  Search       0.53      0.43      0.47        49
#                Security       0.51      0.61      0.56        36
#                Shipping       0.77      0.94      0.85        32
#                  Social       0.52      0.46      0.48        35
#                  Sports       0.95      0.84      0.89        45
#                  Stocks       0.91      0.93      0.92        44
#                 Storage       0.84      0.90      0.87        41
#               Telephony       0.58      0.63      0.60        41
#                   Tools       0.43      0.29      0.35        34
#          Transportation       0.61      0.63      0.62        43
#                  Travel       0.70      0.72      0.71        32
#                   Video       0.73      0.90      0.80        39
#                 Weather       0.89      0.93      0.91        42
#               eCommerce       0.55      0.62      0.58        42
#
#                accuracy                           0.75      2000
#               macro avg       0.75      0.75      0.74      2000
#            weighted avg       0.74      0.75      0.74      2000
#
#
# Confusion Matrix:
# TFIDF + SBERT with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.78      0.71      0.74        41
#               Analytics       0.83      0.97      0.90        36
# Application Development       0.84      0.76      0.80        34
#                 Backend       0.78      0.85      0.81        41
#                 Banking       0.85      0.94      0.89        36
#                 Bitcoin       0.88      0.91      0.90        33
#                    Chat       0.98      0.98      0.98        45
#                   Cloud       0.68      0.79      0.73        34
#                    Data       0.70      0.78      0.74        36
#                Database       0.88      0.73      0.80        41
#                 Domains       0.88      0.98      0.93        45
#               Education       0.86      0.73      0.79        49
#                   Email       0.79      0.74      0.77        42
#              Enterprise       0.48      0.28      0.35        50
#           Entertainment       0.86      0.91      0.89        35
#                  Events       0.83      0.87      0.85        39
#            File Sharing       0.95      1.00      0.97        39
#               Financial       0.73      0.51      0.60        37
#                   Games       0.82      0.82      0.82        34
#              Government       0.66      0.72      0.69        46
#                  Images       0.92      0.90      0.91        51
#      Internet of Things       0.79      0.98      0.88        43
#                 Mapping       0.84      0.82      0.83        39
#               Marketing       0.83      0.87      0.85        46
#                   Media       0.86      0.94      0.90        32
#                 Medical       0.86      0.88      0.87        43
#               Messaging       0.68      0.79      0.73        34
#                   Music       0.95      0.90      0.92        40
#           News Services       0.90      0.90      0.90        40
#                   Other       0.68      0.72      0.70        32
#                Payments       0.79      0.76      0.78        41
#                  Photos       0.81      0.98      0.89        48
#      Project Management       0.77      0.85      0.80        39
#             Real Estate       0.95      0.86      0.90        42
#               Reference       0.38      0.37      0.38        41
#                 Science       0.68      0.56      0.61        41
#                  Search       0.52      0.47      0.49        49
#                Security       0.51      0.53      0.52        36
#                Shipping       0.84      1.00      0.91        32
#                  Social       0.46      0.37      0.41        35
#                  Sports       0.95      0.87      0.91        45
#                  Stocks       0.93      0.98      0.96        44
#                 Storage       0.86      0.90      0.88        41
#               Telephony       0.77      0.66      0.71        41
#                   Tools       0.41      0.32      0.36        34
#          Transportation       0.76      0.79      0.77        43
#                  Travel       0.85      0.88      0.86        32
#                   Video       0.80      0.85      0.82        39
#                 Weather       0.84      0.98      0.90        42
#               eCommerce       0.60      0.64      0.62        42
#
#                accuracy                           0.79      2000
#               macro avg       0.78      0.79      0.78      2000
#            weighted avg       0.78      0.79      0.78      2000
#
#
# Confusion Matrix:
# SBERT (Scaled) with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.82      0.66      0.73        41
#               Analytics       0.69      0.92      0.79        36
# Application Development       0.73      0.79      0.76        34
#                 Backend       0.78      0.95      0.86        41
#                 Banking       0.88      0.97      0.92        36
#                 Bitcoin       0.94      0.91      0.92        33
#                    Chat       0.96      1.00      0.98        45
#                   Cloud       0.68      0.76      0.72        34
#                    Data       0.75      0.83      0.79        36
#                Database       0.75      0.73      0.74        41
#                 Domains       0.78      0.93      0.85        45
#               Education       0.66      0.51      0.57        49
#                   Email       0.85      0.69      0.76        42
#              Enterprise       0.32      0.26      0.29        50
#           Entertainment       0.91      0.86      0.88        35
#                  Events       0.87      0.87      0.87        39
#            File Sharing       0.89      1.00      0.94        39
#               Financial       0.63      0.32      0.43        37
#                   Games       0.90      0.76      0.83        34
#              Government       0.52      0.50      0.51        46
#                  Images       0.87      0.88      0.87        51
#      Internet of Things       0.70      0.72      0.71        43
#                 Mapping       0.76      0.79      0.78        39
#               Marketing       0.85      0.87      0.86        46
#                   Media       0.91      0.94      0.92        32
#                 Medical       0.93      0.93      0.93        43
#               Messaging       0.59      0.68      0.63        34
#                   Music       0.97      0.90      0.94        40
#           News Services       0.95      0.88      0.91        40
#                   Other       0.59      0.72      0.65        32
#                Payments       0.72      0.63      0.68        41
#                  Photos       0.85      0.94      0.89        48
#      Project Management       0.79      0.77      0.78        39
#             Real Estate       0.82      0.86      0.84        42
#               Reference       0.37      0.32      0.34        41
#                 Science       0.53      0.46      0.49        41
#                  Search       0.54      0.45      0.49        49
#                Security       0.50      0.61      0.55        36
#                Shipping       0.75      0.94      0.83        32
#                  Social       0.47      0.46      0.46        35
#                  Sports       1.00      0.84      0.92        45
#                  Stocks       0.91      0.93      0.92        44
#                 Storage       0.80      0.85      0.82        41
#               Telephony       0.56      0.61      0.58        41
#                   Tools       0.43      0.35      0.39        34
#          Transportation       0.60      0.60      0.60        43
#                  Travel       0.72      0.72      0.72        32
#                   Video       0.74      0.87      0.80        39
#                 Weather       0.89      0.93      0.91        42
#               eCommerce       0.55      0.55      0.55        42
#
#                accuracy                           0.74      2000
#               macro avg       0.74      0.74      0.74      2000
#            weighted avg       0.74      0.74      0.74      2000
#
#
# Confusion Matrix:
# TFIDF + SBERT (Scaled) with 50 Web Services Classification Report:
#
#                          precision    recall  f1-score   support
#
#             Advertising       0.74      0.68      0.71        41
#               Analytics       0.85      0.92      0.88        36
# Application Development       0.72      0.76      0.74        34
#                 Backend       0.81      0.85      0.83        41
#                 Banking       0.85      0.94      0.89        36
#                 Bitcoin       0.83      0.91      0.87        33
#                    Chat       0.96      0.98      0.97        45
#                   Cloud       0.68      0.82      0.75        34
#                    Data       0.70      0.83      0.76        36
#                Database       0.86      0.73      0.79        41
#                 Domains       0.88      0.98      0.93        45
#               Education       0.86      0.73      0.79        49
#                   Email       0.79      0.74      0.77        42
#              Enterprise       0.52      0.30      0.38        50
#           Entertainment       0.82      0.91      0.86        35
#                  Events       0.83      0.87      0.85        39
#            File Sharing       0.95      1.00      0.97        39
#               Financial       0.64      0.43      0.52        37
#                   Games       0.80      0.82      0.81        34
#              Government       0.69      0.72      0.70        46
#                  Images       0.92      0.90      0.91        51
#      Internet of Things       0.78      0.98      0.87        43
#                 Mapping       0.78      0.79      0.78        39
#               Marketing       0.83      0.87      0.85        46
#                   Media       0.86      0.94      0.90        32
#                 Medical       0.89      0.91      0.90        43
#               Messaging       0.65      0.76      0.70        34
#                   Music       0.95      0.90      0.92        40
#           News Services       0.86      0.90      0.88        40
#                   Other       0.73      0.75      0.74        32
#                Payments       0.82      0.76      0.78        41
#                  Photos       0.81      0.98      0.89        48
#      Project Management       0.76      0.82      0.79        39
#             Real Estate       0.92      0.86      0.89        42
#               Reference       0.36      0.37      0.36        41
#                 Science       0.62      0.51      0.56        41
#                  Search       0.61      0.51      0.56        49
#                Security       0.50      0.53      0.51        36
#                Shipping       0.86      1.00      0.93        32
#                  Social       0.50      0.43      0.46        35
#                  Sports       0.93      0.84      0.88        45
#                  Stocks       0.93      0.98      0.96        44
#                 Storage       0.90      0.90      0.90        41
#               Telephony       0.72      0.63      0.68        41
#                   Tools       0.43      0.26      0.33        34
#          Transportation       0.83      0.79      0.81        43
#                  Travel       0.84      0.81      0.83        32
#                   Video       0.76      0.82      0.79        39
#                 Weather       0.84      0.98      0.90        42
#               eCommerce       0.63      0.64      0.64        42
#
#                accuracy                           0.78      2000
#               macro avg       0.77      0.78      0.77      2000
#            weighted avg       0.77      0.78      0.77      2000
#
#
# Confusion Matrix:

# %% [markdown]
# ### 11.1 Web Service Classification using XGBoost - Summary

# %%
results_df = pd.DataFrame(xg_model_results)
print(results_df)
df_plot = results_df.set_index('model')
df_plot.plot(kind='bar', figsize=(12, 6))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')
plt.ylim(0.7, 0.95)
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
#                                                model  accuracy  precision  \
# 0         XGBClassifier  TF-IDF with 50 Web Services    0.7585   0.752152
# 1          XGBClassifier  SBERT with 50 Web Services    0.7490   0.744936
# 2  XGBClassifier  TFIDF + SBERT with 50 Web Services    0.7850   0.779059
# 3  XGBClassifier  SBERT (Scaled) with 50 Web Serv...    0.7420   0.738456
# 4  XGBClassifier  TFIDF + SBERT (Scaled) with 50 ...    0.7810   0.774171
#
#    recall  f1_score
# 0  0.7585  0.751539
# 1  0.7490  0.742628
# 2  0.7850  0.778855
# 3  0.7420  0.736516
# 4  0.7810  0.774171

# %% [markdown]
# ## 12. Summary

# %%
combined_results = lr_model_results + rf_model_results + xg_model_results
df_combined = pd.DataFrame(combined_results)

# Plotting
df_plot_combined = df_combined.set_index('model')
df_plot_combined.plot(kind='bar', figsize=(14, 7))
plt.title('Model Performance Comparison (LR, RF, XGB)')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')
plt.ylim(0.7, 0.9)
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
df_plot_combined
# Out:
#                                                     accuracy  precision  \
# model
# LogisticRegression  TF-IDF with 50 Web Services       0.7275   0.730765
# LogisticRegression  SBERT with 50 Web Services        0.6650   0.657351
# LogisticRegression  TFIDF + SBERT with 50 Web S...    0.7635   0.763657
# LogisticRegression  SBERT(Scaled) with 50 Web S...    0.7545   0.749648
# LogisticRegression  TFIDF + SBERT (Scaled) with...    0.7565   0.752347
# RandomForestClassifier  TF-IDF with 50 Web Serv...    0.7670   0.759564
# RandomForestClassifier  SBERT with 50 Web Services    0.7725   0.770878
# RandomForestClassifier  TFIDF + SBERT with 50 W...    0.7875   0.781136
# RandomForestClassifier  SBERT(Scaled) with 50  ...    0.7665   0.764510
# RandomForestClassifier  TFIDF + SBERT(Scaled) w...    0.7800   0.770788
# XGBClassifier  TF-IDF with 50 Web Services            0.7585   0.752152
# XGBClassifier  SBERT with 50 Web Services             0.7490   0.744936
# XGBClassifier  TFIDF + SBERT with 50 Web Services     0.7850   0.779059
# XGBClassifier  SBERT (Scaled) with 50 Web Services    0.7420   0.738456
# XGBClassifier  TFIDF + SBERT (Scaled) with 50 W...    0.7810   0.774171
#
#                                                     recall  f1_score
# model
# LogisticRegression  TF-IDF with 50 Web Services     0.7275  0.725825
# LogisticRegression  SBERT with 50 Web Services      0.6650  0.655140
# LogisticRegression  TFIDF + SBERT with 50 Web S...  0.7635  0.760546
# LogisticRegression  SBERT(Scaled) with 50 Web S...  0.7545  0.748555
# LogisticRegression  TFIDF + SBERT (Scaled) with...  0.7565  0.750796
# RandomForestClassifier  TF-IDF with 50 Web Serv...  0.7670  0.757237
# RandomForestClassifier  SBERT with 50 Web Services  0.7725  0.764863
# RandomForestClassifier  TFIDF + SBERT with 50 W...  0.7875  0.777438
# RandomForestClassifier  SBERT(Scaled) with 50  ...  0.7665  0.758588
# RandomForestClassifier  TFIDF + SBERT(Scaled) w...  0.7800  0.769155
# XGBClassifier  TF-IDF with 50 Web Services          0.7585  0.751539
# XGBClassifier  SBERT with 50 Web Services           0.7490  0.742628
# XGBClassifier  TFIDF + SBERT with 50 Web Services   0.7850  0.778855
# XGBClassifier  SBERT (Scaled) with 50 Web Services  0.7420  0.736516
# XGBClassifier  TFIDF + SBERT (Scaled) with 50 W...  0.7810  0.774171
